# %%
import docx
from docx import Document
from docx.text.paragraph import Paragraph
from docx.enum.text import WD_PARAGRAPH_ALIGNMENT
from docx.table import Table
import itertools
import re
import os
import pandas as pd
import fitz
import pdfplumber

from langchain_community.vectorstores import Chroma
from langchain.prompts import ChatPromptTemplate, PromptTemplate
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_core.messages import HumanMessage
from langchain_openai import AzureOpenAI, AzureChatOpenAI
from langchain_openai.embeddings import AzureOpenAIEmbeddings
from langchain.schema.runnable import RunnablePassthrough
from langchain.schema.output_parser import StrOutputParser

# %%
ref_file_path = r"C:\Users\320271965\Desktop\project 1 Traceability\BI\Data\DHF345094_RequirementsTraceabilityMatrix_UNS_SRS_AzurionR3 0 Rev A.xlsx"

uns_file_path = r"C:\Users\320271965\Desktop\project 1 Traceability\BI\Data\DHF335296_Azurion R3.0_Puma_UNS.docx"

srs_file_path = r"C:\Users\320271965\Desktop\project 1 Traceability\BI\Data\DHF334523_SRS_Azurion_R3.0_RevF.docx"

# %%
df_ref = pd.read_excel(ref_file_path, sheet_name='Traceability Matrix', engine='openpyxl')
df_ref_grouped = df_ref.groupby('User Needs Specification Tag')['System Requirements Specification Tag'].apply(lambda x: list(set(x))).reset_index()
output_file_path = r'C:\Users\320271965\Desktop\project 1 Traceability\BI\Data\df_traceability_matrix.xlsx'
df_ref_grouped.to_excel(output_file_path, index=False)
print(f"Grouped data has been saved to {output_file_path}")
df_ref_grouped
# Out:
# Grouped data has been saved to C:\Users\320271965\Desktop\project 1 Traceability\BI\Data\df_traceability_matrix.xlsx
#                 User Needs Specification Tag  \
# 0        Not applicable, no user requirement
# 1    UNS.SmartSuite.2DQAAccuracyAndPrecision
# 2    UNS.SmartSuite.2DQAAutomatedMeasurement
# 3             UNS.SmartSuite.2DQACalibration
# 4          UNS.SmartSuite.2DQAEfficientToUse
# ..                                       ...
# 181                UNS.SmartSuite.ViewingROI
# 182                  UNS.SmartSuite.Workspot
# 183          UNS.SmartSuite.X-rayBeamShaping
# 184    UNS.SmartSuite.X-rayDetectorFieldSize
# 185           UNS.SmartSuite.processingfocus
#
#                  System Requirements Specification Tag
# 0    [SRS.Allura.Manf.VerifySystem, SRS.Allura.Phys...
# 1    [SRS.Allura.Func.VesselAnalysis.Accuracy, SRS....
# 2    [SRS.Allura.Func.VesselAnalysis, SRS.Allura.Fu...
# 3                      [SRS.Allura.Func.QACalibration]
# 4    [SRS.Allura.Func.VesselAnalysis, SRS.Allura.Fu...
# ..                                                 ...
# 181  [SRS.Allura.Func.AngulateBeam, SRS.Allura.Func...
# 182  [SRS.Allura.Intgr.Interfaces.RealTimeImageLink...
# 183  [SRS.Allura.Func.Move/ResetWedges, SRS.Allura....
# 184  [SRS.Allura.Conf.SupportedConfigurations, SRS....
# 185            [SRS.Allura.Func.SelectProcessingFocus]
#
# [186 rows x 2 columns]

# %%
system_requirements_spec = df_ref_grouped['System Requirements Specification Tag']

# Display the column values
system_requirements_spec
# Out:
# 0      [SRS.Allura.Manf.VerifySystem, SRS.Allura.Phys...
# 1      [SRS.Allura.Func.VesselAnalysis.Accuracy, SRS....
# 2      [SRS.Allura.Func.VesselAnalysis, SRS.Allura.Fu...
# 3                        [SRS.Allura.Func.QACalibration]
# 4      [SRS.Allura.Func.VesselAnalysis, SRS.Allura.Fu...
#                              ...
# 181    [SRS.Allura.Func.AngulateBeam, SRS.Allura.Func...
# 182    [SRS.Allura.Intgr.Interfaces.RealTimeImageLink...
# 183    [SRS.Allura.Func.Move/ResetWedges, SRS.Allura....
# 184    [SRS.Allura.Conf.SupportedConfigurations, SRS....
# 185              [SRS.Allura.Func.SelectProcessingFocus]
# Name: System Requirements Specification Tag, Length: 186, dtype: object

# %%
user_needs_spec = df_ref_grouped['User Needs Specification Tag']

# Display the column values
user_needs_spec
# Out:
# 0          Not applicable, no user requirement
# 1      UNS.SmartSuite.2DQAAccuracyAndPrecision
# 2      UNS.SmartSuite.2DQAAutomatedMeasurement
# 3               UNS.SmartSuite.2DQACalibration
# 4            UNS.SmartSuite.2DQAEfficientToUse
#                         ...
# 181                  UNS.SmartSuite.ViewingROI
# 182                    UNS.SmartSuite.Workspot
# 183            UNS.SmartSuite.X-rayBeamShaping
# 184      UNS.SmartSuite.X-rayDetectorFieldSize
# 185             UNS.SmartSuite.processingfocus
# Name: User Needs Specification Tag, Length: 186, dtype: object

# %%
file_path=r'C:\Users\320271965\Desktop\project 1 Traceability\BI\IGT_BI\srs_content_nd_tags.xlsx'
df=pd.read_excel(file_path)
srs_data = []
for srs_record in system_requirements_spec:
    #print(srs_record)
    extracted_content=""
    for srs_tag in srs_record:
        print(srs_tag)
        result=df[df.iloc[:,0]==srs_tag]
        if not result.empty:
            content = result.iloc[0, 1]
            if pd.isna(content):
                content = ""  
            else:
                content = str(content)  
            
            extracted_content += content        
    srs_data.append([srs_record, extracted_content])
    #print(data)    
output_df2 = pd.DataFrame(srs_data, columns=['srs_record', 'extracted_content']) 
output_file_path = r'C:\Users\320271965\Desktop\project 1 Traceability\BI\IGT_BI\traceability with srs content.xlsx'
output_df2.to_excel(output_file_path, index=False)

print(f"Data has been successfully written to {output_file_path}")
# Out:
# SRS.Allura.Manf.VerifySystem
# SRS.Allura.I&V.Environment
# SRS.Allura.Phys.TechnicalRoomCabinetsSpace
# SRS.Allura.I&V.TestInterface
# SRS.Allura.SLS.ECO.EnergyConsumption
# SRS.Allura.Manf.LoadConfiguration
# SRS.Allura.I&V.ManualTest
# SRS.Allura.Func.VentricularAnalysisAccuracy
# SRS.Allura.Func.VesselAnalysis.Accuracy
# SRS.Allura.Func.VesselAnalysis
# SRS.Allura.Func.VentricularAnalysis
# SRS.Allura.Func.QA
# SRS.Allura.Func.QACalibration
# SRS.Allura.Func.VesselAnalysis
# SRS.Allura.Func.VentricularAnalysis
# SRS.Allura.Func.QA
# SRS.Allura.Func.DualPhaseXperCT
# SRS.Allura.Func.ClassicDRA
# SRS.Allura.Func.DRAFor3D
# SRS.Allura.Func.XperCT
# SRS.Allura.Func.DualPhaseXperCT
# SRS.Allura.Func.ClassicDRA
# SRS.Allura.Func.DRAFor3D
# SRS.Allura.Func.XperCT
# SRS.Allura.Func.DisplayFluoroTime
# SRS.Allura.Conf.ImageStorageOptions
# SRS.Allura.Func.ChangeFluoroProcessing
# SRS.Allura.Qual.IQContrastResolution2D
# SRS.Allura.Func.ActivateExposure
# SRS.Allura.Func.DoseControlTechniques
# SRS.Allura.Func.SelectDetectorFieldsize
# SRS.Allura.Qual.IQWorkingPoint
# SRS.Allura.Func.SingleShotFootpedal
# SRS.Allura.Qual.IQArtifactsSubjective
# SRS.Allura.Qual.IQLimitingResolutionSystemLevel
# SRS.Allura.Qual.IQBeamAlignment
# SRS.Allura.Func.DisplayInfo
# SRS.Allura.Func.ExposureFramespeed
# SRS.Allura.Func.PresettingFunctions
# SRS.Allura.Func.IntegratedExposure
# SRS.Allura.Qual.IQKVStabilized
# SRS.Allura.Func.DoseControlMeasuringFields
# SRS.Allura.Qual.IQDisplaySignalTransfer
# SRS.Allura.Qual.ClinicalResponseTimes.Acquisition
# SRS.Allura.Func.FluoroFlavours
# SRS.Allura.Qual.IQX-rayOutput
# SRS.Allura.Func.DisplayAndReportPatientDose
# SRS.Allura.Qual.IQmAsStabilized
# SRS.Allura.Func.ExposureTechniques
# SRS.Allura.Func.TimedVariableFramerates
# SRS.Allura.Qual.IQBrightnessUniformity
# SRS.Allura.Func.RunLogging
# SRS.Allura.Func.AntiScatterGrid
# SRS.Allura.Qual.X-rayPerformance
# SRS.Allura.Qual.IQHalfValueLayer
# SRS.Allura.Func.X-rayFiltering
# SRS.Allura.Qual.IQGeoStability
# SRS.Allura.Func.ActivateFluoro
# SRS.Allura.Func.ManualOverrideEPXParameterValues
# SRS.Allura.Conf.UI-RelatedItems
# SRS.Allura.Func.AutomaticElectronicShutters
# SRS.Allura.Func.High-DoseFluoroProtection
# SRS.Allura.Qual.IQScatterReduction
# SRS.Allura.Func.StoreFluoro
# SRS.Allura.Func.AcquisitionMethods
# SRS.Allura.Func.ActivateFluoro
# SRS.Allura.Conf.UI-RelatedItems
# SRS.Allura.Func.ContrastInjection
# SRS.Allura.Func.SingleShotFootpedal
# SRS.Allura.Func.SelectActiveChannel
# SRS.Allura.Func.ActivateExposure
# SRS.Allura.Func.SetInjectorCoupling
# SRS.Allura.Intgr.WLMSystems
# SRS.Allura.Intgr.Flexvision
# SRS.Allura.Func.ModifyStudy
# SRS.Allura.Func.AddStudy
# SRS.Allura.Intgr.NonDICOMWLMSystems
# SRS.Allura.Intgr.Flexvision.KeyboardMouse
# SRS.Allura.Intgr.Flexspot.AdditionalWorkspot
# SRS.Allura.Func.Merge
# SRS.Allura.Func.Workflow.Flexibility
# SRS.Allura.Intgr.Interfaces.DataExchange
# SRS.Allura.SLS.IHE
# SRS.Allura.Conf.Control-RoomDisplays
# SRS.Allura.Intgr.Flexspot.AdditionalWorkspot
# SRS.Allura.Intgr.Flexspot.SecondFlexspot
# SRS.Allura.Serv.SiteLog
# SRS.Allura.Serv.SystemID
# SRS.Allura.Serv.Backup/Restore
# SRS.Allura.UI.ComfortThemes
# SRS.Allura.Func.OverrideManualAdjustments
# SRS.Allura.Func.ModifyStudy
# SRS.Allura.Func.SelectProcessingFocus
# SRS.Allura.Func.PredefinedAnnotation
# SRS.Allura.Func.ManualAnnotation
# SRS.Allura.Func.SelectProcessingScope
# SRS.Security.MD.PhysicalAccess
# SRS.Security.PHD.PhysicalAccess
# SRS.Allura.Func.APCCommon
# SRS.Allura.Func.APC3DReference
# SRS.Allura.Func.APCPathway
# SRS.Allura.Func.SystemCustomization
# SRS.Allura.Func.APCStore/Recall
# SRS.Allura.Func.APCTable
# SRS.Allura.Func.ModifyEPXParameters
# SRS.Allura.Func.APCReference
# SRS.Allura.Func.APCPredefined
# SRS.Allura.Intgr.DoseAwareXtend
# SRS.Allura.Intgr.OpenVideoInterface.LargeScreenDownscaled
# SRS.Allura.Intgr.Magnus
# SRS.Allura.Intgr.4KVideoInputOutput
# SRS.Allura.Intgr.Flexvision.KeyboardMouse
# SRS.Allura.Intgr.Injectors
# SRS.Allura.Intgr.KVM-Switching
# SRS.Allura.Intgr.PhysioEquipment(ECG)
# SRS.Allura.Conf.MCS-RelatedItems
# SRS.Allura.Conf.Table-RelatedItems
# SRS.Allura.Intgr.Interfaces.AuxiliarySystemMounting
# SRS.Allura.Intgr.FHDVideoSources
# SRS.Allura.Func.SetInjectorCoupling
# SRS.Allura.Intgr.VideoSlave
# SRS.Allura.Intgr.OpenVideoInterface.LargeScreen
# SRS.Allura.Intgr.Flexvision
# SRS.Allura.Intgr.EquipmentRack
# SRS.Allura.Intgr.Flexspot.AdditionalWorkspot
# SRS.Allura.Conf.RemainingComponents
# SRS.Allura.Intgr.Flexspot
# SRS.Allura.Intgr.Multivision
# SRS.Allura.Intgr.Interfaces.ControlFromAuxiliarySystems
# SRS.Allura.Intgr.TruSystem
# SRS.Allura.Intgr.Interfaces.DataExchange
# SRS.Allura.Func.PhysioAcquisition
# SRS.Allura.Intgr.Interfaces.RealTimeImageLink
# SRS.Allura.Intgr.Interfaces.ControlAuxiliarySystems
# SRS.Allura.Intgr.Flexspot.KeyboardMouse
# SRS.Allura.Conf.UI-RelatedItems
# SRS.Allura.Intgr.VideoDisplayInterface
# SRS.Allura.Intgr.AblationEquipment
# SRS.Allura.Intgr.SwitchableMonitors
# SRS.Allura.Conf.XperFDSeriesConfigurations
# SRS.Allura.Intgr.ImageExportImport
# SRS.Allura.Func.ContrastInjection
# SRS.Allura.Func.SetInjectorCoupling
# SRS.Allura.Func.BiplaneAcquisition
# SRS.Allura.Func.SelectActiveChannel
# SRS.Allura.Func.BiplaneAcquisition
# SRS.Allura.Func.Z-RotateStandBase(L-ArmRotation)
# SRS.Allura.Func.AcquisitionMethods
# SRS.Allura.Func.StoreFluoro
# SRS.Allura.Func.ActivateFluoro
# SRS.Allura.Conf.UI-RelatedItems
# SRS.Allura.Func.SelectActiveChannel
# SRS.Allura.Func.ActivateExposure
# SRS.Allura.Func.SingleShotFootpedal
# SRS.Allura.Func.BiplaneAcquisition
# SRS.Allura.Func.BolusChaseReconstruction
# SRS.Allura.Func.Dual-AxisAcquisition
# SRS.Allura.Conf.Stand-RelatedItems
# SRS.Allura.Conf.Stand-RelatedItems
# SRS.Allura.Func.RotateFDXDDetector
# SRS.Allura.Func.ImageBeamRotation
# SRS.Allura.Func.StoreFluoro
# SRS.Allura.Func.AcquisitionMethods
# SRS.Allura.Func.ActivateFluoro
# SRS.Allura.Conf.UI-RelatedItems
# SRS.Allura.Func.ContrastInjection
# SRS.Allura.Func.SingleShotFootpedal
# SRS.Allura.Func.SelectActiveChannel
# SRS.Allura.Func.ActivateExposure
# SRS.Allura.Func.SetInjectorCoupling
# SRS.Allura.SLS.patient-contamination
# SRS.Allura.UI.Help
# SRS.Allura.UI.Help.Customize
# SRS.Allura.Phys.Cleanability
# SRS.Allura.UI.TSM.Image
# SRS.Allura.Intgr.Magnus
# SRS.Allura.SLS.collision-harm-reduction
# SRS.Allura.SLS.collision-unintend-ui
# SRS.Allura.SLS.collision-avoidance
# SRS.Allura.Func.OverrideMovementsBlockage
# SRS.Allura.Intgr.TruSystem
# SRS.Allura.SLS.unexpected-manual-behavior
# SRS.Allura.SLS.movement-integrity
# SRS.Allura.SLS.careless-manual-operation
# SRS.Allura.Phys.LaminarAirflowCompatibility
# SRS.Allura.Func.X-rayImageProcessing
# SRS.Allura.Func.ExposureSubtract
# SRS.Allura.Func.DICOM.Export
# SRS.Allura.Func.Roadmap.AutomaticPixelShift
# SRS.Allura.Func.NormalSubtraction
# SRS.Allura.UI.UIModule
# SRS.Allura.Conf.UI-RelatedItems
# SRS.Allura.UI.Workspot
# SRS.Allura.SLS.ListOfApplicableStandards
# SRS.Allura.Func.AngulateBeam
# SRS.Allura.Func.RotateBeam
# SRS.Allura.Intgr.Flexspot
# SRS.Allura.UI.KeyboardMouse
# SRS.Allura.Intgr.Flexspot.KeyboardMouse
# SRS.Allura.Intgr.AuxiliarySystems
# SRS.Allura.Func.ShowStudyInfo
# SRS.Allura.SLS.IHE
# SRS.Allura.Func.AddStudy
# SRS.Allura.Func.ModifyStudy
# SRS.Allura.Func.StoreToMedia
# SRS.Allura.Func.DICOM.Export
# SRS.Allura.Func.ShowStudyInfo
# SRS.Allura.Func.RunLogging
# SRS.Allura.Func.CopyImages
# SRS.Allura.Func.DisplayStudyList
# SRS.Allura.UI.Help
# SRS.Allura.Serv.FSInstructions
# SRS.Allura.Func.DeleteRun
# SRS.Allura.Func.Protect/UnprotectStudy
# SRS.Allura.Func.DeleteStudy
# SRS.Allura.Serv.Adjust
# SRS.Allura.Qual.FSResponseTimes
# SRS.Allura.Serv.SystemMonitoring&Alerting
# SRS.Allura.Serv.NetworkDiagnosis
# SRS.Allura.Intgr.Interfaces.RemoteConnectionSettings
# SRS.Allura.UI.ServiceUILanguage
# SRS.Allura.Serv.RemoteSFTP
# SRS.Allura.Serv.FunctionalTests
# SRS.Allura.Serv.SystemInformation.Remote
# SRS.Security.MD.RemoteAccessPoint
# SRS.Allura.Serv.Maintenance.Predictive
# SRS.Allura.Serv.Logging
# SRS.Allura.Serv.UserInterface
# SRS.Allura.Serv.RemoteConnectivityStatus
# SRS.Allura.Serv.HardwareTests
# SRS.Allura.Serv.SystemInformation
# SRS.Allura.Func.Diagnostics
# SRS.Allura.Func.FinishStudy
# SRS.Allura.Func.SystemCustomization
# SRS.Allura.Func.Workflow.Flexibility
# SRS.Allura.Func.DICOM.Import
# SRS.Allura.Func.DICOM.Query
# SRS.Allura.Qual.ClinicalResponseTimes.Arch
# SRS.Allura.Func.DICOM.Export
# SRS.Allura.SLS.IHE
# SRS.Allura.Intgr.ImageExportImport
# SRS.Allura.Func.DICOM.Export/ImportJobManagement
# SRS.Allura.Func.DICOM.Consistency
# SRS.Allura.Intgr.OpenVideoInterface.LargeScreenDownscaled
# SRS.Allura.Intgr.Flexvision.KeyboardMouse
# SRS.Allura.Func.Roadmap.DevicePhase.LiveSubtract
# SRS.Allura.Func.ActivateExposure
# SRS.Allura.UI.TSM.Image
# SRS.Allura.Conf.MCS-RelatedItems
# SRS.Allura.Intgr.VideoSlave
# SRS.Allura.Func.Roadmap.DevicePhase.VesselUnSubtract
# SRS.Allura.Func.Select/DeselectStopwatch
# SRS.Allura.Intgr.OpenVideoInterface.LargeScreen
# SRS.Allura.Intgr.Flexvision
# SRS.Allura.UI.PositionMCSFrame
# SRS.Allura.Conf.Control-RoomDisplays
# SRS.Allura.Func.Roadmap.DevicePhase.VesselSubtract
# SRS.Allura.Intgr.Flexspot.AdditionalWorkspot
# SRS.Allura.Func.DisplayInfo
# SRS.Allura.SLS.ListOfApplicableStandards
# SRS.Allura.Intgr.AdditionalMultiView
# SRS.Allura.Func.NavigateToImageData
# SRS.Allura.Intgr.Flexspot
# SRS.Allura.Intgr.MultiView
# SRS.Allura.Intgr.Multivision
# SRS.Allura.Intgr.3rdAnd4thMultiView
# SRS.Allura.Func.ActivateFluoro
# SRS.Allura.Intgr.Flexspot.KeyboardMouse
# SRS.Allura.Intgr.VideoDisplayInterface
# SRS.Allura.Intgr.SwitchableMonitors
# SRS.Allura.Func.Roadmap.DevicePhase
# SRS.Allura.Func.DoorContact
# SRS.Allura.Func.DisplayAndReportPatientDose
# SRS.Allura.Conf.UI-RelatedItems
# SRS.Allura.Func.Move/ResetWedges
# SRS.Allura.Func.Move/ResetShutters
# SRS.Allura.Conf.RemainingComponents
# SRS.Allura.Func.FluoroFlavours
# SRS.Allura.Func.StoreToMedia
# SRS.Allura.Func.Reporting.Dose
# SRS.Allura.Func.DICOM.Import
# SRS.Allura.Func.DICOM.Export
# SRS.Allura.Func.DICOM.DoseStructuredReport
# SRS.Allura.Func.DualFluoro
# SRS.Allura.Func.AcquisitionZoom
# SRS.Allura.Func.StoreReferenceRun/Image
# SRS.Allura.Func.DualPhaseXperCT
# SRS.Allura.Func.ClassicDRA
# SRS.Allura.Func.DRAFor3D
# SRS.Allura.Func.XperCT
# SRS.Allura.Intgr.PhysioEquipment(ECG)
# SRS.Allura.Func.EPTriggering
# SRS.Allura.Func.StripeFilter
# SRS.Allura.Func.ProcedureCard
# SRS.Allura.Func.PresettingFunctions
# SRS.Allura.Func.EPX
# SRS.Allura.Func.ModifyEPXParameters
# SRS.Allura.Func.ModifySelectionTree
# SRS.Allura.Func.StoreToMedia
# SRS.Allura.Func.Import/ExportOfClinicalImages
# SRS.Allura.Intgr.Media
# SRS.Allura.Func.MoveBeamXY
# SRS.Allura.Func.EmergencyStop
# SRS.Allura.Func.EmergencyPowerDown
# SRS.Allura.Func.ImplicitSelectionDefaultStudy
# SRS.Allura.Func.TableLock
# SRS.Allura.Func.MoveBeam
# SRS.Allura.Qual.ClinicalResponseTimes.System
# SRS.Allura.Intgr.Flexspot.AdditionalWorkspot
# SRS.Allura.Func.ReopenFinishedStudy
# SRS.Allura.Func.FinishStudy
# SRS.Allura.Func.SelectStudyFromSuspendedList
# SRS.Allura.SLS.ListOfApplicableStandards
# SRS.Allura.SLS.ECO.ProductLabeling
# SRS.Allura.Serv.Field-ServiceAccessPoints
# SRS.Allura.Serv.RemoteSFTP
# SRS.Allura.Serv.SystemInformation.Remote
# SRS.Allura.Serv.RetrieveInformation
# SRS.Allura.Serv.RemoteDesktop.ServiceMode
# SRS.Allura.Serv.RemoteImageTransfer
# SRS.Allura.Serv.RemoteAccessAndConnection
# SRS.Allura.Qual.ClinicalResponseTimes.Admin
# SRS.Allura.Func.PhysicianSpecificSettings
# SRS.Allura.Func.EPX
# SRS.Allura.Func.PresettingFunctions
# SRS.Allura.SLS.xray-imaging-failure-detection-and-fault-tolerant
# SRS.Allura.Func.ExceptionHandling
# SRS.Allura.SLS.movements-failure-detection-and-fault-tolerant
# SRS.Allura.Func.DisplayServiceGuidance
# SRS.Allura.Func.TubeLoadProtectionAndIndication
# SRS.Allura.SLS.maintain-minimal-functionality
# SRS.Allura.Qual.ClinicalResponseTimes.System
# SRS.Allura.Func.GracefulDegradation
# SRS.Allura.Func.DisplayUserMessages
# SRS.Allura.Func.DICOM.Export
# SRS.Allura.Func.Flagging
# SRS.Allura.Qual.ClinicalResponseTimes.Acquisition
# SRS.Allura.SLS.image-latency
# SRS.Allura.Conf.SupportedConfigurations
# SRS.Allura.Conf.XperFDSeriesConfigurations
# SRS.Allura.Conf.SupportedConfigurations
# SRS.Allura.Conf.XperFDSeriesConfigurations
# SRS.Allura.Conf.SupportedConfigurations
# SRS.Allura.Conf.XperFDSeriesConfigurations
# SRS.Allura.Func.BolusChaseReconstruction
# SRS.Allura.Func.RunSubtract
# SRS.Allura.Func.FreeInteractiveFDPA
# SRS.Allura.Serv.Logging
# SRS.Allura.Func.Flagging
# SRS.Allura.Func.MoveBeamXY
# SRS.Allura.Func.APCStore/Recall
# SRS.Allura.Func.MoveBeamXY
# SRS.Allura.Conf.Stand-RelatedItems
# SRS.Allura.Conf.UI-RelatedItems
# SRS.Allura.Func.MoveBeamXY
# SRS.Allura.SLS.patient-contamination
# SRS.Allura.SLS.patient-contamin-airborne
# SRS.Allura.Func.MoveBeamXY
# SRS.Allura.Func.ParkorStandbyBeam
# SRS.Allura.Conf.Control-RoomDisplays
# SRS.Allura.Intgr.Flexspot.KeyboardMouse
# SRS.Allura.Intgr.VideoDisplayInterface
# SRS.Allura.Intgr.Flexspot.AdditionalWorkspot
# SRS.Allura.Intgr.AuxiliarySystems
# SRS.Allura.Intgr.OpticalImagingSystem
# SRS.Allura.Intgr.VideoSourcesMaintainIQ
# SRS.Allura.Intgr.VideoInputInterface
# SRS.Allura.Intgr.Flexspot
# SRS.Allura.Intgr.Flexspot.SecondFlexspot
# SRS.Allura.Intgr.OpenVideoInterface.LargeScreenDownscaled
# SRS.Allura.Intgr.OpenVideoInterface.LargeScreen
# SRS.Allura.Intgr.Flexvision
# SRS.Allura.Intgr.Interfaces.ControlAuxiliarySystems
# SRS.Allura.Intgr.Flexspot.KeyboardMouse
# SRS.Allura.Intgr.Flexvision.KeyboardMouse
# SRS.Allura.Intgr.VideoDisplayInterface
# SRS.Allura.Intgr.NativeIQ
# SRS.Allura.Intgr.Interfaces.ControlFromAuxiliarySystems
# SRS.Allura.Intgr.Flexvision.Snapshot
# SRS.Allura.Intgr.OpticalImagingSystem
# SRS.Allura.Intgr.VideoSourcesMaintainIQ
# SRS.Allura.Intgr.VideoInputInterface
# SRS.Allura.Intgr.Flexspot
# SRS.Allura.UI.ComfortThemes
# SRS.Allura.Intgr.Interfaces.RealTimeImageLink
# SRS.Allura.Func.Z-RotateStandBase(L-ArmRotation)
# SRS.Allura.Func.RotateFDXDDetector
# SRS.Allura.Func.PatientOrientedMovement
# SRS.Allura.Intgr.Flexvision
# SRS.Allura.Intgr.Flexspot.KeyboardMouse
# SRS.Allura.Intgr.Flexvision.KeyboardMouse
# SRS.Allura.Intgr.VideoDisplayInterface
# SRS.Allura.Intgr.Flexspot.AdditionalWorkspot
# SRS.Allura.Intgr.Flexspot
# SRS.Allura.Func.IndicateRadiationOn
# SRS.Allura.Func.FluoroTimeBuzzer
# SRS.Allura.Func.RoomLightAndOperationLamp
# SRS.Allura.Func.ImageBeamRotation
# SRS.Allura.Func.RotateBeam
# SRS.Allura.Func.ParkorStandbyBeam
# SRS.Allura.Func.DualPhaseXperCT
# SRS.Allura.Func.ClassicDRA
# SRS.Allura.Func.DRAFor3D
# SRS.Allura.Func.XperCT
# SRS.Allura.Func.MoveBeamXY
# SRS.Security.MD.PhysicalAccess
# SRS.Security.PHD.PhysicalDismounting
# SRS.Security.HN.HospitalNetworkBreached
# SRS.Security.PHD.HospitalNetwork
# SRS.Security.HN.RemovableMediaBreached
# SRS.Security.MD.MalwareOnRemovable media
# SRS.Security.HN.AttackViaMedicalDevice
# SRS.Security.PHD.PatientDataCorrupted
# SRS.Security.PHD.MedicalDevice
# SRS.Security.MD.AttackViaPhysical DeviceModification
# SRS.Security.PHD.RemoteAccessPoint
# SRS.Security.MD.HospitalNetwork
# SRS.Security.MD.RemoteAccessPoint
# SRS.Security.RM.AttackViaMedicalDevice
# SRS.Security.MD.DataBreach
# SRS.Security.PHD.DataBreach
# SRS.Security.PHD.PhysicalAccess
# SRS.Security.PHD.PatientDataLoss
# SRS.Security.MD.ReputationDamage
# SRS.Security.MD.UnavailabilityOfMedicalDevice
# SRS.Allura.Serv.SystemInformation.Export
# SRS.Allura.Serv.SiteLog
# SRS.Allura.Serv.AcceptanceTestReport
# SRS.Security.MD.RemoteAccessPoint
# SRS.Allura.Serv.SystemID
# SRS.Allura.Func.SystemCustomization
# SRS.Allura.Func.X-rayImageProcessing
# SRS.Allura.Func.AcquisitionMethods
# SRS.Allura.Intgr.Interfaces.DataExchange
# SRS.Allura.Func.OverrideManualAdjustments
# SRS.Allura.Func.PanZoom
# SRS.Allura.Func.VideoInvert
# SRS.Allura.Func.SetImageEnhancement
# SRS.Allura.Qual.ClinicalResponseTimes.Review
# SRS.Allura.Func.MoveBeamXY
# SRS.Allura.Func.OverrideManualAdjustments
# SRS.Allura.Func.OverlayText
# SRS.Allura.Func.VideoInvert
# SRS.Allura.Func.StoreToMedia
# SRS.Allura.Func.ChangeFluoroProcessing
# SRS.Allura.Func.PredefinedAnnotation
# SRS.Allura.Func.Roadmap.DevicePhase.Processing
# SRS.Allura.Func.ManualAnnotation
# SRS.Allura.Qual.ClinicalResponseTimes.Review
# SRS.Allura.Func.SetImageEnhancement
# SRS.Allura.Func.Tracing
# SRS.Allura.Func.SelectPhysioDisplay
# SRS.Allura.Func.DICOM.Export
# SRS.Allura.Func.CO2Tracing
# SRS.Allura.Func.NormalSubtraction
# SRS.Allura.Func.SelectProcessingScope
# SRS.Allura.Func.Roadmap.DevicePhase.VesselSubtract
# SRS.Allura.Func.ExposureSubtract
# SRS.Allura.Func.Roadmap.DevicePhase.Subtraction
# SRS.Allura.Func.Roadmap.DevicePhase.LiveSubtract
# SRS.Allura.Func.AcquisitionMaskAveraging
# SRS.Allura.Func.Roadmap.DevicePhase.DeviceMask
# SRS.Allura.Func.RunSubtract
# SRS.Allura.Func.NormalSubtraction
# SRS.Allura.Qual.ClinicalResponseTimes.Acquisition
# SRS.Allura.Func.ReopenFinishedStudy
# SRS.Allura.Func.FinishStudy
# SRS.Allura.Func.StoreToMedia
# SRS.Allura.Func.DICOM.Export
# SRS.Allura.SLS.IHE
# SRS.Allura.Func.DICOM.Export/ImportJobManagement
# SRS.Allura.Func.Move/ResetWedges
# SRS.Allura.Func.TableTilting
# SRS.Allura.Func.APCStore/Recall
# SRS.Allura.Func.SelectDetectorFieldsize
# SRS.Allura.Func.APCPredefined
# SRS.Allura.Func.EmergencyStop
# SRS.Allura.Func.SwingStandBase
# SRS.Allura.Func.Move/ResetShutters
# SRS.Allura.Func.TableLock
# SRS.Allura.Func.MoveBeam
# SRS.Allura.Func.Z-RotateStandBase(L-ArmRotation)
# SRS.Allura.Qual.ClinicalResponseTimes.Movement
# SRS.Allura.Func.FluoroTimeBuzzer
# SRS.Allura.Func.TableCradle
# SRS.Allura.Func.FluoroFlavours
# SRS.Allura.Func.ChangingTableHeight
# SRS.Allura.Func.SelectTableSide
# SRS.Allura.Func.APC3DReference
# SRS.Allura.Func.AngulateBeam
# SRS.Allura.Func.APCTable
# SRS.Allura.Func.RotateBeam
# SRS.Allura.Func.ChangeSIDByDetector
# SRS.Allura.Func.Roadmap.SmartMask
# SRS.Allura.Func.APCReference
# SRS.Allura.Func.MoveBeamXY
# SRS.Allura.Func.StoreFluoro
# SRS.Allura.Conf.UI-RelatedItems
# SRS.Allura.Func.ResetGeometry
# SRS.Allura.Func.RotateFDXDDetector
# SRS.Allura.Func.Roadmap
# SRS.Allura.Func.PositioningTableTop
# SRS.Allura.Func.BiplaneAcquisition
# SRS.Allura.Func.ContrastInjection
# SRS.Allura.Conf.RemainingComponents
# SRS.Allura.Func.SetInjectorCoupling
# SRS.Allura.Intgr.Injectors
# SRS.Allura.Serv.Maintenance.Planned
# SRS.Allura.UI.Help
# SRS.Allura.Func.ProcedureCard
# SRS.Allura.UI.Help.Customize
# SRS.Allura.Intgr.DoseAwareXtend
# SRS.Allura.UI.Help
# SRS.Allura.Serv.RemoteSWInstall
# SRS.Allura.SLS.ListOfApplicableStandards
# SRS.Allura.UI.Help
# SRS.Allura.UI.Help
# SRS.Allura.Func.Intercom
# SRS.Allura.Func.ExceptionHandling
# SRS.Allura.Func.PositioningIndicationWithoutRadiation
# SRS.Allura.UI.Clinical-UILanguage
# SRS.Allura.Func.Cycle
# SRS.Allura.Func.LastImageHoldOrAutoCycle
# SRS.Allura.Func.StoreFluoro
# SRS.Allura.Func.RoomLightAndOperationLamp
# SRS.Allura.Intgr.Interfaces.ControlAuxiliarySystems
# SRS.Allura.Func.DualPhaseXperCT
# SRS.Allura.Func.Dual-AxisAcquisition
# SRS.Allura.Intgr.Interfaces.ControlFromAuxiliarySystems
# SRS.Allura.Func.ClassicDRA
# SRS.Allura.Func.DRAFor3D
# SRS.Allura.Func.XperCT
# SRS.Allura.Intgr.Interfaces.RealTimeImageLink
# SRS.Allura.Func.ActivateFluoro
# SRS.Allura.Intgr.4KVideoInputOutput
# SRS.Allura.Func.StoreReferenceRun/Image
# SRS.Allura.Intgr.NativeIQ
# SRS.Allura.Func.DVDRecordControl
# SRS.Allura.Func.ActivateExposure
# SRS.Allura.Func.SingleShotFootpedal
# SRS.Allura.Intgr.FHDVideoSources
# SRS.Allura.Qual.ClinicalResponseTimes.Acquisition
# SRS.Allura.Intgr.DVDRecorders
# SRS.Allura.Conf.ImageStorageOptions
# SRS.Allura.Func.StoreToMedia
# SRS.Allura.Func.RetrieveFromMedia
# SRS.Allura.Intgr.Media
# SRS.Allura.Func.Z-RotateStandBase(L-ArmRotation)
# SRS.Allura.Func.SelectTableSide
# SRS.Allura.Func.SwingStandBase
# SRS.Allura.Func.MoveBeam
# SRS.Allura.Func.Marker
# SRS.Allura.Func.Measurement
# SRS.Allura.UI.Help
# SRS.Allura.Serv.FSTools
# SRS.Allura.Serv.FSInstructions
# SRS.Allura.UI.Help
# SRS.Allura.Serv.FSInstructions
# SRS.Allura.Serv.SingleLabConnection
# SRS.Allura.UI.PositionMCSFrame
# SRS.Allura.Conf.MCS-RelatedItems
# SRS.Allura.Func.ParkorStandbyBeam
# SRS.Allura.Func.ParkorStandbyBeam
# SRS.Allura.UI.UIModule
# SRS.Allura.UI.Design.FlexibleViewing
# SRS.Allura.Func.ProcedureCard
# SRS.Allura.UI.KeyboardMouse
# SRS.Allura.Func.PresettingFunctions
# SRS.Allura.UI.Design.Application
# SRS.Allura.UI.UIModule
# SRS.Allura.Intgr.Magnus
# SRS.Allura.Conf.UI-RelatedItems
# SRS.Allura.Intgr.TruSystem
# SRS.Allura.Conf.Table-RelatedItems
# SRS.Allura.SLS.movement-integrity
# SRS.Allura.Func.MovementDisable/Enable
# SRS.Allura.SLS.unexpected-manual-behavior
# SRS.Allura.Func.Z-RotateStandBase(L-ArmRotation)
# SRS.Allura.Func.RotateFDXDDetector
# SRS.Allura.Func.RotateBeam
# SRS.Allura.UI.Help
# SRS.Allura.Serv.FSInstructions
# SRS.Allura.Intgr.Flexvision
# SRS.Allura.Intgr.Multivision
# SRS.Allura.Intgr.SwitchableMonitors
# SRS.Allura.Func.Concurrency
# SRS.Allura.Func.PriorityConstraints
# SRS.Allura.Func.ParkorStandbyBeam
# SRS.Allura.Func.MoveBeamXY
# SRS.Allura.Func.SwingStandBase
# SRS.Allura.Func.AngulateBeam
# SRS.Allura.Func.RotateFDXDDetector
# SRS.Allura.Func.APCStore/Recall
# SRS.Allura.Func.APCTable
# SRS.Allura.Func.MoveBeam
# SRS.Allura.Func.RotateBeam
# SRS.Allura.Func.Z-RotateStandBase(L-ArmRotation)
# SRS.Allura.Func.ChangeSIDByDetector
# SRS.Allura.Qual.ClinicalResponseTimes.Movement
# SRS.Allura.Func.DisplayActualPosition
# SRS.Allura.Func.XperCT
# SRS.Allura.Conf.Table-RelatedItems
# SRS.Allura.Func.Merge
# SRS.Allura.Func.ProcedureCard
# SRS.Allura.Func.ImplicitSelectionDefaultStudy
# SRS.Allura.SLS.consistent-patient-and-image-data
# SRS.Allura.Func.DisplayAndReportPatientDose
# SRS.Allura.SLS.consistent-image-orientation
# SRS.Allura.Conf.SupportedConfigurations
# SRS.Allura.Func.SelectSurgicalView
# SRS.Allura.Func.PatientOrientation
# SRS.Allura.Func.PatientOrientedMovement
# SRS.Allura.Func.ChangingTableHeight
# SRS.Allura.Func.SelectTableSide
# SRS.Allura.Func.DisplayOrientation
# SRS.Allura.Func.TableLock
# SRS.Allura.Func.DisplayActualPosition
# SRS.Allura.Func.PositioningTableTop
# SRS.Allura.SLS.patient-contamination
# SRS.Allura.UI.Workspot
# SRS.Allura.Conf.UI-RelatedItems
# SRS.Allura.Func.SelectPhysioDisplay
# SRS.Allura.Intgr.PhysioEquipment(ECG)
# SRS.Allura.Func.PhysioAcquisition
# SRS.Allura.UI.Image.Pointer
# SRS.Allura.Conf.RemainingComponents
# SRS.Allura.Func.PowerFailureBehaviour
# SRS.Allura.Intgr.AuxiliarySystems
# SRS.Allura.Intgr.BackupPowerActive
# SRS.Allura.Conf.Table-RelatedItems
# SRS.Allura.Intgr.ExternalThreePhaseUPS
# SRS.Allura.Qual.ClinicalResponseTimes.Arch
# SRS.Allura.SLS.IHE
# SRS.Allura.Func.DICOM.Import
# SRS.Allura.Serv.FunctionalTests
# SRS.Allura.Serv.NetworkDiagnosis
# SRS.Allura.Serv.RemoteConnectivityStatus
# SRS.Allura.Serv.HardwareTests
# SRS.Allura.Intgr.NetworkFilmPrinters
# SRS.Allura.Intgr.LocalPaperPrinters
# SRS.Allura.Func.PrintSheetCreation
# SRS.Allura.Qual.ClinicalResponseTimes.Arch
# SRS.Allura.Func.PrintJobControl
# SRS.Allura.Func.PatientOrientation
# SRS.Allura.Func.ProcedureCard
# SRS.Allura.Func.PredefinedAnnotation
# SRS.Allura.Func.SystemCustomization
# SRS.Allura.Func.Workflow.Flexibility
# SRS.Allura.UI.Help.Customize
# SRS.Allura.Intgr.WLMSystems
# SRS.Allura.Func.FinishStudy
# SRS.Allura.Func.SelectStudyFromScheduledList
# SRS.Allura.Func.ShowStudyInfo
# SRS.Allura.SLS.IHE
# SRS.Allura.Func.VesselAnalysis
# SRS.Allura.Func.VentricularAnalysis
# SRS.Allura.Func.QA
# SRS.Allura.SLS.ListOfApplicableStandards
# SRS.Allura.Intgr.Flexvision
# SRS.Allura.Func.APCCommon
# SRS.Allura.Func.APC3DReference
# SRS.Allura.Func.APCStore/Recall
# SRS.Allura.Intgr.Flexvision.Snapshot
# SRS.Allura.Func.APCTable
# SRS.Allura.Func.APCReference
# SRS.Allura.Conf.Stand-RelatedItems
# SRS.Allura.Func.Roadmap.AutomaticPixelShift
# SRS.Allura.UI.UIModule
# SRS.Allura.Conf.UI-RelatedItems
# SRS.Allura.Func.Cycle
# SRS.Allura.Qual.ClinicalResponseTimes.Review
# SRS.Allura.Func.NavigateToImageData
# SRS.Allura.Func.MosaicOverview
# SRS.Allura.Func.Roadmap.DevicePhase.VesselUnSubtract
# SRS.Allura.Func.Roadmap.DevicePhase.Misregistration
# SRS.Allura.Func.Roadmap.DevicePhase.VesselSubtract
# SRS.Allura.Func.Roadmap.DevicePhase.Subtraction
# SRS.Allura.Func.Roadmap.VesselPhase
# SRS.Allura.Func.Roadmap.DevicePhase.Processing
# SRS.Allura.Func.Roadmap.DevicePhase.LiveSubtract
# SRS.Allura.Func.Roadmap.DevicePhase.DeviceMask
# SRS.Allura.Func.Roadmap.Mode
# SRS.Allura.Func.Roadmap.AutomaticPixelShift
# SRS.Allura.Func.Roadmap
# SRS.Allura.Func.Roadmap.SmartMask
# SRS.Allura.Func.Roadmap.DevicePhase
# SRS.Allura.Qual.ClinicalResponseTimes.Acquisition
# SRS.Allura.Qual.ClinicalResponseTimes.3D-Acquisition
# SRS.Allura.Func.MoveBeamXY
# SRS.Allura.UI.PositionMCSFrame
# SRS.Allura.SLS.patient-contamination
# SRS.Allura.Func.SwingStandBase
# SRS.Allura.Func.MoveBeam
# SRS.Allura.Func.SelectActiveChannel
# SRS.Allura.Func.Z-RotateStandBase(L-ArmRotation)
# SRS.Allura.SLS.patient-contamin-airborne
# SRS.Allura.Conf.MCS-RelatedItems
# SRS.Allura.Phys.LaminarAirflowCompatibility
# SRS.Allura.Func.ClassicDRA
# SRS.Allura.SLS.patient-contamination
# SRS.Allura.SLS.careless-operator-patient-fall
# SRS.Allura.SLS.movements-failure-detection-and-fault-tolerant
# SRS.Allura.SLS.fse-safety
# SRS.Allura.SLS.tipping-equipment
# SRS.Allura.SLS.acoustic-noise
# SRS.Allura.SLS.electr-shock-prevention-fse
# SRS.Allura.Phys.ClimaticEnvironmentalConditions
# SRS.Allura.SLS.structural-integrity
# SRS.Allura.SLS.patient-move-collision
# SRS.Allura.SLS.prevent-using-incorrect-in-patient-measurements
# SRS.Allura.SLS.replay-path-free
# SRS.Allura.Func.EnableRemoteServiceAccess
# SRS.Allura.SLS.unexpected-manual-behavior
# SRS.Allura.Func.SwitchSystemPowerOn
# SRS.Allura.SLS.DoD
# SRS.Allura.SLS.careless-manual-operation
# SRS.Allura.SLS.fse-contamin
# SRS.Allura.SLS.collision-harm-reduction
# SRS.Allura.SLS.xray-imaging-failure-detection-and-fault-tolerant
# SRS.Allura.SLS.radiation-patient-dose
# SRS.Allura.SLS.safe-surfaces
# SRS.Allura.SLS.ListOfApplicableStandards
# SRS.Allura.SLS.intended-image-quality
# SRS.Allura.Phys.ElectromagneticCompatibility(EMC)
# SRS.Allura.SLS.consistent-patient-and-image-data
# SRS.Allura.SLS.consistent-image-orientation
# SRS.Allura.Serv.RemoteInterference
# SRS.Allura.SLS.collision-unintend-ui
# SRS.Allura.SLS.peripheral-equipment
# SRS.Allura.SLS.thermal-safety
# SRS.Allura.SLS.correct-overlay
# SRS.Allura.SLS.electr-shock-prev-staff-patient
# SRS.Allura.SLS.prevent-lih-live-mixup
# SRS.Allura.Phys.MainsPower
# SRS.Allura.Func.RemoteServiceActiveIndication
# SRS.Allura.SLS.movement-integrity
# SRS.Allura.SLS.radiation-user-dose
# SRS.Allura.SLS.unintend-ui-patient-falling
# SRS.Allura.SLS.table-movement-integrity
# SRS.Allura.SLS.collision-avoidance
# SRS.Allura.Phys.MechanicalEnvironmentalConditions
# SRS.Allura.SLS.maintain-minimal-functionality
# SRS.Allura.SLS.patient-move-fall
# SRS.Allura.SLS.patient-contamin-airborne
# SRS.Allura.SLS.injector-safety
# SRS.Allura.SLS.image-latency
# SRS.Security.PHD.PhysicalDismounting
# SRS.Security.MD.PhysicalAccess
# SRS.Security.HN.HospitalNetworkBreached
# SRS.Security.HN.RemovableMediaBreached
# SRS.Allura.Func.EnableRemoteServiceAccess
# SRS.Security.MD.MalwareOnRemovable media
# SRS.Security.HN.AttackViaMedicalDevice
# SRS.Allura.SLS.DoD
# SRS.Security.PHD.PatientDataCorrupted
# SRS.Security.PHD.MedicalDevice
# SRS.Security.MD.AttackViaPhysical DeviceModification
# SRS.Security.PHD.RemoteAccessPoint
# SRS.Security.MD.HospitalNetwork
# SRS.Security.MD.RemoteAccessPoint
# SRS.Security.RM.AttackViaMedicalDevice
# SRS.Security.MD.DataBreach
# SRS.Security.MD.UnavailabilityOfMedicalDevice
# SRS.Allura.Serv.RemoteInterference
# SRS.Allura.Serv.AccessRightsAndAuthorization
# SRS.Allura.Func.RemoteServiceActiveIndication
# SRS.Security.PHD.DataBreach
# SRS.Security.PHD.PhysicalAccess
# SRS.Security.PHD.PatientDataLoss
# SRS.Security.MD.ReputationDamage
# SRS.Security.PHD.HospitalNetwork
# SRS.Allura.Serv.Adjust
# SRS.Allura.Qual.ClinicalResponseTimes.System
# SRS.Allura.Qual.FSResponseTimes
# SRS.Allura.SLS.xray-imaging-failure-detection-and-fault-tolerant
# SRS.Allura.SLS.movements-failure-detection-and-fault-tolerant
# SRS.Allura.Serv.Configure
# SRS.Allura.Func.TubeLoadProtectionAndIndication
# SRS.Allura.Qual.IQFactory/ServiceMeasurements
# SRS.Allura.UI.ServiceUILanguage
# SRS.Allura.SLS.maintain-minimal-functionality
# SRS.Allura.Func.ExceptionHandling
# SRS.Allura.Func.SystemRestart
# SRS.Allura.Serv.UserInterface
# SRS.Allura.Func.GracefulDegradation
# SRS.Allura.Func.DisplayServiceGuidance
# SRS.Allura.Func.DisplayUserMessages
# SRS.Allura.Serv.Customize
# SRS.Allura.Func.SwitchSystemPowerOff
# SRS.Allura.Qual.ClinicalResponseTimes.System
# SRS.Allura.Serv.SingleLabConnection
# SRS.Allura.Serv.Maintenance.Planned
# SRS.Allura.Conf.MinimalRoomSize
# SRS.Allura.SLS.movement-integrity
# SRS.Allura.Func.PriorityConstraints
# SRS.Allura.Func.SelectTableSide
# SRS.Allura.SLS.unexpected-manual-behavior
# SRS.Allura.Serv.Upgrading
# SRS.Allura.Serv.InstallSoftware
# SRS.Allura.Serv.RemoteConnectivityStatus
# SRS.Allura.Phys.Noise
# SRS.Allura.SLS.acoustic-noise
# SRS.Allura.Func.ReopenFinishedStudy
# SRS.Allura.Intgr.Flexspot.AdditionalWorkspot
# SRS.Allura.Func.SelectStudyFromScheduledList
# SRS.Allura.Qual.ClinicalResponseTimes.Admin
# SRS.Allura.Func.SelectStudyFromSuspendedList
# SRS.Allura.Func.X-RayDisable/Enable
# SRS.Allura.Func.SwitchSystemPowerOn.VideoOnly
# SRS.Allura.Func.SwitchSystemPowerOn
# SRS.Allura.Qual.ClinicalResponseTimes.System
# SRS.Allura.Phys.MainsPower
# SRS.Allura.UI.UIModule
# SRS.Allura.Conf.Stand-RelatedItems
# SRS.Allura.UI.TSM.Workspot
# SRS.Allura.Phys.Noise
# SRS.Allura.Intgr.Interfaces.ControlAuxiliarySystems
# SRS.Allura.UI.TSM.Workspot
# SRS.Allura.Intgr.Interfaces.ControlAuxiliarySystems
# SRS.Allura.Intgr.Flexvision.KeyboardMouse
# SRS.Allura.Func.ChangingTableHeight
# SRS.Allura.Func.MovementDisable/Enable
# SRS.Allura.Func.TableTilting
# SRS.Allura.Func.PivotRotationTableBase
# SRS.Allura.Func.TableCradle
# SRS.Allura.Func.PositioningTableTop
# SRS.Allura.Conf.Table-RelatedItems
# SRS.Allura.Func.SwivelMovementTableBase
# SRS.Allura.Conf.Table-RelatedItems
# SRS.Allura.Func.ChangingTableHeight
# SRS.Allura.Func.TableTilting
# SRS.Allura.Func.PivotRotationTableBase
# SRS.Allura.Qual.ClinicalResponseTimes.Movement
# SRS.Allura.Func.TableCradle
# SRS.Allura.Func.PositioningTableTop
# SRS.Allura.Func.SwivelMovementTableBase
# SRS.Allura.Intgr.Flexvision.KeyboardMouse
# SRS.Allura.Intgr.Flexvision
# SRS.Allura.UI.Help
# SRS.Allura.Func.ProcedureCard
# SRS.Allura.UI.Help.Customize
# SRS.Allura.Serv.Adjust
# SRS.Allura.Qual.FSResponseTimes
# SRS.Allura.Func.ServiceStudies
# SRS.Allura.Qual.IQFactory/ServiceMeasurements
# SRS.Allura.Intgr.Interfaces.ServiceDataRetrieval
# SRS.Allura.Serv.VerificationTests
# SRS.Allura.Serv.AcceptanceTestReport
# SRS.Allura.Serv.Logging
# SRS.Allura.Serv.UserInterface
# SRS.Allura.UI.ServiceUILanguage
# SRS.Allura.UI.UIModule
# SRS.Allura.Func.Move/ResetWedges
# SRS.Allura.Intgr.Flexvision.KeyboardMouse
# SRS.Allura.Func.APCStore/Recall
# SRS.Allura.Func.DynamicViewing
# SRS.Allura.UI.TSM.Image
# SRS.Allura.Func.APCPredefined
# SRS.Allura.Intgr.Flexvision
# SRS.Allura.UI.Workspot
# SRS.Allura.Func.Move/ResetShutters
# SRS.Allura.Func.Cycle
# SRS.Allura.Func.PresettingFunctions
# SRS.Allura.Func.PanZoom
# SRS.Allura.UI.TSM.Workspot
# SRS.Allura.Func.APC3DReference
# SRS.Allura.Func.APCTable
# SRS.Allura.Intgr.Interfaces.ControlFromAuxiliarySystems
# SRS.Allura.Func.APCReference
# SRS.Allura.Intgr.Interfaces.RealTimeImageLink
# SRS.Allura.Intgr.Interfaces.ControlAuxiliarySystems
# SRS.Allura.Conf.UI-RelatedItems
# SRS.Allura.Func.SetImageEnhancement
# SRS.Allura.UI.Image.Pointer
# SRS.Allura.Func.NormalSubtraction
# SRS.Allura.UI.TSM.Workspot
# SRS.Allura.Func.ChangingTableHeight
# SRS.Allura.Intgr.Magnus
# SRS.Allura.Func.TableLock
# SRS.Allura.Phys.ClimaticEnvironmentalConditions
# SRS.Allura.Phys.MechanicalEnvironmentalConditions
# SRS.Allura.Serv.FSInstructions
# SRS.Allura.Intgr.Interfaces.ControlAuxiliarySystems
# SRS.Allura.Intgr.Interfaces.RealTimeImageLink
# SRS.Allura.Intgr.Interfaces.ControlFromAuxiliarySystems
# SRS.Allura.Intgr.Interfaces.DataExchange
# SRS.Allura.Func.SelectTableSide
# SRS.Allura.Conf.UI-RelatedItems
# SRS.Allura.Serv.RemoteDesktop.ClinicalMode
# SRS.Allura.Func.Concurrency
# SRS.Allura.UI.TSM.Image
# SRS.Allura.Func.PriorityConstraints
# SRS.Allura.Func.SelectTableSide
# SRS.Allura.Func.PatientOrientation
# SRS.Allura.Func.DisplayOrientation
# SRS.Allura.Func.RotateBeam
# SRS.Allura.Func.SelectSurgicalView
# SRS.Allura.Func.BeamShapingControls
# SRS.Allura.Func.Display/SetTimeAndDate
# SRS.Allura.Func.SystemCustomization
# SRS.Allura.Func.ModifyPhysicianList
# SRS.Allura.UI.Help.Customize
# SRS.Allura.Conf.Stand-RelatedItems
# SRS.Allura.SLS.VA
# SRS.Allura.Intgr.VideoSlave
# SRS.Allura.Intgr.VideoDisplayInterface
# SRS.Allura.Intgr.SwitchableMonitors
# SRS.Allura.Func.Cycle
# SRS.Allura.Qual.ClinicalResponseTimes.Review
# SRS.Allura.Func.NavigateToImageData
# SRS.Allura.Func.SwitchDisplayFocus
# SRS.Allura.Func.DynamicViewing
# SRS.Allura.Func.ShowStudyInfo
# SRS.Allura.Func.SelectViewingStudy
# SRS.Allura.Func.MosaicOverview
# SRS.Allura.Func.DisplayStudyList
# SRS.Allura.Func.AngulateBeam
# SRS.Allura.Func.RotateBeam
# SRS.Allura.Intgr.Interfaces.ControlAuxiliarySystems
# SRS.Allura.UI.TSM.Workspot
# SRS.Allura.UI.Workspot
# SRS.Allura.Intgr.Interfaces.ControlFromAuxiliarySystems
# SRS.Allura.Intgr.Interfaces.RealTimeImageLink
# SRS.Allura.Func.Move/ResetWedges
# SRS.Allura.Func.Move/ResetShutters
# SRS.Allura.Func.ShutterAndWedgeIndicationWithoutRadiation
# SRS.Allura.Qual.ClinicalResponseTimes.Movement
# SRS.Allura.Func.BeamShapingControls
# SRS.Allura.Func.SetElectronicShutters
# SRS.Allura.UI.TSM.Image
# SRS.Allura.Func.AutomaticWedgeFollowing
# SRS.Allura.Func.SelectDetectorFieldsize
# SRS.Allura.Conf.SupportedConfigurations
# SRS.Allura.Conf.XperFDSeriesConfigurations
# SRS.Allura.Func.SelectProcessingFocus
# Data has been successfully written to C:\Users\320271965\Desktop\project 1 Traceability\BI\IGT_BI\traceability with srs content.xlsx

# %%
doc_path = r'C:\Users\320271965\Desktop\project 1 Traceability\BI\Data\DHF334523_SRS_Azurion_R3.0_RevF.docx'
srs_doc = docx.Document(doc_path)

# Provided function to extract content under each tag
def extract_content_and_tables_after_tag(srs_doc, srs_tag):
    elements = []  # List to hold text and tables in order
    tag_found = False
    processing_content = False
    in_exclusion_section = False  # Variable to handle multiple exclusion sections
    content_found = False
    table_found = False

    def starts_with_srs_tag(text, tag_start):
        """Check if text starts with a specific tag."""
        return text.startswith(tag_start)

    def is_another_srs_tag(text):
        return text.startswith('SRS.')

    def is_heading(text):
        """Check if text is a heading."""
        return text.startswith('Heading')

    # Iterate through elements (paragraphs and tables) in the document body
    for element in srs_doc.element.body:
        if isinstance(element, docx.oxml.CT_P):  # Check for paragraphs
            para = docx.text.paragraph.Paragraph(element, srs_doc)
            para_text = para.text

            # Check if we are in an exclusion section
            if 'LIST OF REQUIREMENT TAGS' in para_text or 'Revision History' in para_text:
                in_exclusion_section = True
            elif para.style.name.startswith('Heading') and in_exclusion_section:
                in_exclusion_section = False

            if not in_exclusion_section:
                if starts_with_srs_tag(para_text, srs_tag):
                    if tag_found:  # If another uid_tag is found, stop
                        break
                    tag_found = True
                    processing_content = True
                    continue

                if processing_content:
                    if is_another_srs_tag(para_text) or is_heading(para_text):
                        break  # Stop if another uid_tag is found
                    elements.append(('text', para_text))
                    content_found = True

        elif isinstance(element, docx.oxml.CT_Tbl):  # Check for tables
            if processing_content:
                table = docx.table.Table(element, srs_doc)
                table_data = [[cell.text for cell in row.cells] for row in table.rows]
                elements.append(('table', table_data))
                table_found = True

    return elements if content_found or table_found else []

# Convert extracted content into a format suitable for Excel
output_data = []

for tag_list in system_requirements_spec:
    if isinstance(tag_list, list):  # Ensure it's a list
        combined_content = ""  # To hold combined content for all tags in the current tag_list

        # Process each tag in the current tag_list
        for tag in tag_list:
            elements = extract_content_and_tables_after_tag(srs_doc, tag)
            
            # Combine content for this tag
            for element_type, data in elements:
                if element_type == "text":
                    combined_content += data + "\n"
                elif element_type == "table":
                    table_str = "\n".join(["\t".join(row) for row in data])
                    combined_content += f"Table:\n{table_str}\n"

        # Append the combined content for the current tag_list
        output_data.append([" | ".join(tag_list), combined_content.strip()])

# Save the output to an Excel file
output_df = pd.DataFrame(output_data, columns=['SRS Tags (Combined)', 'Content'])
output_df.to_excel(r'C:\Users\320271965\Desktop\project 1 Traceability\BI\Data\traceability_with_combinedsrs_content.xlsx', index=False)

print("Content for each tag list has been saved.")

# Save the output to an Excel file
output_df = pd.DataFrame(output_data, columns=['SRS Tags (Combined)', 'Content'])
output_df.to_excel(r'C:\Users\320271965\Desktop\project 1 Traceability\BI\Data\traceability with srs content.xlsx', index=False)

print("Content under each tag, including tables, has been saved.")
# Out:
# Content for each tag list has been saved.
# Content under each tag, including tables, has been saved.

# %%
file_path=r'C:\Users\320271965\Desktop\project 1 Traceability\BI\IGT_BI\processed_uns_tags_with_tables.xlsx'
df=pd.read_excel(file_path)
uns_data = []

for uns_tag in user_needs_spec:
    extracted_content=""
    print(uns_tag)
    result=df[df.iloc[:,0]==uns_tag]
    if not result.empty:
        extracted_content=result.iloc[0,1]
    uns_data.append([uns_tag, extracted_content])    
    #print(extracted_content) 
output_df1 = pd.DataFrame(uns_data, columns=['uns_tag', 'extracted_content'])    
output_file_path = r'C:\Users\320271965\Desktop\project 1 Traceability\BI\IGT_BI\traceability with uns content.xlsx'
output_df1.to_excel(output_file_path, index=False)

print(f"Data has been successfully written to {output_file_path}")
# Out:
# Not applicable, no user requirement
# UNS.SmartSuite.2DQAAccuracyAndPrecision
# UNS.SmartSuite.2DQAAutomatedMeasurement
# UNS.SmartSuite.2DQACalibration
# UNS.SmartSuite.2DQAEfficientToUse
# UNS.SmartSuite.3DAnatomyScan
# UNS.SmartSuite.3Dacquisition
# UNS.SmartSuite.AcquisitionImageQualityAndDose
# UNS.SmartSuite.ActivateFluoroExposure
# UNS.SmartSuite.AddPatientData
# UNS.SmartSuite.AdditionalFlexSpot
# UNS.SmartSuite.Administration
# UNS.SmartSuite.AmbientVideos
# UNS.SmartSuite.Annotations
# UNS.SmartSuite.AuthorizedUser
# UNS.SmartSuite.AutomaticPositionControl
# UNS.SmartSuite.AuxiliarySystems
# UNS.SmartSuite.BiplaneContrast
# UNS.SmartSuite.BiplaneFocusSelection
# UNS.SmartSuite.BiplaneHeadSpace
# UNS.SmartSuite.BiplaneRealTime
# UNS.SmartSuite.BolusChaseReconstruction
# UNS.SmartSuite.CardiacSwing
# UNS.SmartSuite.Carriage
# UNS.SmartSuite.CeilingCompatibility
# UNS.SmartSuite.ChangeDetectorOrientation
# UNS.SmartSuite.ChangeFluoroExposure
# UNS.SmartSuite.Cleaning
# UNS.SmartSuite.ClinicalImagesOnTSM
# UNS.SmartSuite.CollisionDetection
# UNS.SmartSuite.CompatibilityLAF
# UNS.SmartSuite.CompensatePatientMovements
# UNS.SmartSuite.ControlModule
# UNS.SmartSuite.ControlRoomDesign
# UNS.SmartSuite.CreateWorklist
# UNS.SmartSuite.DataHandler
# UNS.SmartSuite.Decommission
# UNS.SmartSuite.DeleteRun
# UNS.SmartSuite.DeleteStudy
# UNS.SmartSuite.Diagnosis
# UNS.SmartSuite.DicomNetworkExporting
# UNS.SmartSuite.DisplayConfiguration
# UNS.SmartSuite.DoorContact
# UNS.SmartSuite.DoseControl
# UNS.SmartSuite.DoseReporting
# UNS.SmartSuite.DualFluoroscopy
# UNS.SmartSuite.DynamicRotationalAngiography
# UNS.SmartSuite.ECGTrigger
# UNS.SmartSuite.EMFieldImageFiltering
# UNS.SmartSuite.EPXtree
# UNS.SmartSuite.EasyUSBExport
# UNS.SmartSuite.Emergency
# UNS.SmartSuite.EndExamination
# UNS.SmartSuite.EnvironmentalCare
# UNS.SmartSuite.Escalation
# UNS.SmartSuite.ExaminationSelectionAndPresetting
# UNS.SmartSuite.ExceptionHandling
# UNS.SmartSuite.ExportApp
# UNS.SmartSuite.EyeHandCoordination
# UNS.SmartSuite.FD12DetectorSize
# UNS.SmartSuite.FD15DetectorSize
# UNS.SmartSuite.FD20DetectorSize
# UNS.SmartSuite.FDPA
# UNS.SmartSuite.FactoriumLogging
# UNS.SmartSuite.Flagging
# UNS.SmartSuite.FlexMove
# UNS.SmartSuite.FlexMoveControl
# UNS.SmartSuite.FlexMoveDesign
# UNS.SmartSuite.FlexMovePark
# UNS.SmartSuite.FlexSpot
# UNS.SmartSuite.FlexVision(Pro)
# UNS.SmartSuite.FlexibleAngles
# UNS.SmartSuite.FlexibleViewing
# UNS.SmartSuite.FluoroIndicators
# UNS.SmartSuite.FreeEndPositions
# UNS.SmartSuite.FromStandbyToWorkingPosition
# UNS.SmartSuite.FullBodyCoverage
# UNS.SmartSuite.HCA
# UNS.SmartSuite.Handover
# UNS.SmartSuite.HospitalITConformance
# UNS.SmartSuite.IQ
# UNS.SmartSuite.ISPWorkflowIntegration
# UNS.SmartSuite.ImageEnhancement
# UNS.SmartSuite.ImageOffCenter
# UNS.SmartSuite.ImageOverlay
# UNS.SmartSuite.ImageSubtraction
# UNS.SmartSuite.ImageTranfer
# UNS.SmartSuite.ImagingControl
# UNS.SmartSuite.InjectorCoupling
# UNS.SmartSuite.InspectCleanLubricate
# UNS.SmartSuite.IntegratedChecklistandProtocols
# UNS.SmartSuite.IntegratedDoseAware
# UNS.SmartSuite.IntegratedHelp
# UNS.SmartSuite.IntegratedIFU
# UNS.SmartSuite.IntegratedTraining
# UNS.SmartSuite.Intercom
# UNS.SmartSuite.IntuitiveCollisionDetectionFeedback
# UNS.SmartSuite.LIHTablePanning
# UNS.SmartSuite.Languages
# UNS.SmartSuite.LastImageHoldOrAutoCycle
# UNS.SmartSuite.LightsAndOperationLamp
# UNS.SmartSuite.LinkWorkstation
# UNS.SmartSuite.LiveImageView
# UNS.SmartSuite.LocalStorage
# UNS.SmartSuite.ManoeuvreBeam
# UNS.SmartSuite.Marker
# UNS.SmartSuite.Measurements
# UNS.SmartSuite.MechanicalInstallation
# UNS.SmartSuite.MechnicalDeinstallation
# UNS.SmartSuite.MonitorConfiguration
# UNS.SmartSuite.MoveToPark
# UNS.SmartSuite.MoveToStandby
# UNS.SmartSuite.NewIdentityUserInterface
# UNS.SmartSuite.ORTable
# UNS.SmartSuite.OperateSystem
# UNS.SmartSuite.OptimalWorkingPosition
# UNS.SmartSuite.PackingandDisposal
# UNS.SmartSuite.ParallelWorking
# UNS.SmartSuite.ParkBeam
# UNS.SmartSuite.PatientAndBeam
# UNS.SmartSuite.PatientComfort
# UNS.SmartSuite.PatientData
# UNS.SmartSuite.PatientDoseFeedback
# UNS.SmartSuite.PatientOrientation
# UNS.SmartSuite.PatientOrientedMovements
# UNS.SmartSuite.PatientPositioning
# UNS.SmartSuite.Pedestal
# UNS.SmartSuite.PhysioAcquisition
# UNS.SmartSuite.PointerOnViewingContainer
# UNS.SmartSuite.PowerFailure
# UNS.SmartSuite.Pre-procedurePlanning
# UNS.SmartSuite.Preparation
# UNS.SmartSuite.Printing
# UNS.SmartSuite.ProcedureCards
# UNS.SmartSuite.ProvideInformation
# UNS.SmartSuite.QA
# UNS.SmartSuite.QualityControl
# UNS.SmartSuite.QuickSaveDuringProcedure
# UNS.SmartSuite.Raillength
# UNS.SmartSuite.ReducePatientMovement
# UNS.SmartSuite.ReviewModule
# UNS.SmartSuite.Roadmap
# UNS.SmartSuite.RollSpeed
# UNS.SmartSuite.RoomSetup
# UNS.SmartSuite.Safe3DScan
# UNS.SmartSuite.SafeSystemUse
# UNS.SmartSuite.SecurityProtection
# UNS.SmartSuite.SettingtoWork
# UNS.SmartSuite.ShutDown
# UNS.SmartSuite.SitePlanning
# UNS.SmartSuite.SiteReadinessCheck
# UNS.SmartSuite.SmallRoom
# UNS.SmartSuite.SmoothInteraction
# UNS.SmartSuite.SoftwareInstallation
# UNS.SmartSuite.SoundsRoom
# UNS.SmartSuite.StartExamination
# UNS.SmartSuite.StartUp
# UNS.SmartSuite.Sterility
# UNS.SmartSuite.SystemNoise
# UNS.SmartSuite.TSMNavigation
# UNS.SmartSuite.TSMPlugandPlay
# UNS.SmartSuite.TSMtouchpad
# UNS.SmartSuite.Table
# UNS.SmartSuite.TableConfiguration
# UNS.SmartSuite.TableSetup
# UNS.SmartSuite.TableSideTextEntry
# UNS.SmartSuite.TaskGuidance
# UNS.SmartSuite.TestandVerification
# UNS.SmartSuite.TouchScreenModule
# UNS.SmartSuite.TouchScreenModuleFluidresistance
# UNS.SmartSuite.TransferPatientFromTable
# UNS.SmartSuite.UnpackandTransport
# UNS.SmartSuite.UseInterventionalTools
# UNS.SmartSuite.UserInterfaceAccess
# UNS.SmartSuite.UserInterfaceOrientationConcepts
# UNS.SmartSuite.UserSpecificSettings
# UNS.SmartSuite.VerticalArmConfiguration
# UNS.SmartSuite.VeteransAdministration
# UNS.SmartSuite.VideoStreamIntegration
# UNS.SmartSuite.VideoSwitching
# UNS.SmartSuite.ViewingNavigation
# UNS.SmartSuite.ViewingROI
# UNS.SmartSuite.Workspot
# UNS.SmartSuite.X-rayBeamShaping
# UNS.SmartSuite.X-rayDetectorFieldSize
# UNS.SmartSuite.processingfocus
# Data has been successfully written to C:\Users\320271965\Desktop\project 1 Traceability\BI\IGT_BI\traceability with uns content.xlsx

# %%
uns_df1=pd.read_excel(r'C:\Users\320271965\Desktop\project 1 Traceability\BI\IGT_BI\traceability with uns content.xlsx')
srs_df1=pd.read_excel(r'C:\Users\320271965\Desktop\project 1 Traceability\BI\Data\traceability with srs content.xlsx')

# %%
# Concatenating horizontally (adding columns)
df_combined = pd.concat([uns_df1, srs_df1], axis=1)
print(df_combined)
output_file_path = r'C:\Users\320271965\Desktop\project 1 Traceability\BI\IGT_BI\1911traceability with uns srs content.xlsx'
df_combined.to_excel(output_file_path, index=False)

print(f"Data has been successfully written to {output_file_path}")
# Out:
#                                      uns_tag  \
# 0        Not applicable, no user requirement
# 1    UNS.SmartSuite.2DQAAccuracyAndPrecision
# 2    UNS.SmartSuite.2DQAAutomatedMeasurement
# 3             UNS.SmartSuite.2DQACalibration
# 4          UNS.SmartSuite.2DQAEfficientToUse
# ..                                       ...
# 181                UNS.SmartSuite.ViewingROI
# 182                  UNS.SmartSuite.Workspot
# 183          UNS.SmartSuite.X-rayBeamShaping
# 184    UNS.SmartSuite.X-rayDetectorFieldSize
# 185           UNS.SmartSuite.processingfocus
#
#                                      extracted_content  \
# 0                                                  NaN
# 1    Clinical images, Systematic error \n[mm], Rand...
# 2    \nHave automatic contour detection in 2DQCA an...
# 3    \nAutomatic and manual calibrate to convert di...
# 4    \nReceive automated assistance when execute ti...
# ..                                                 ...
# 181  \nView from various points the region of inter...
# 182  \nPerform all activities, corresponding to his...
# 183  \nControl the radiated area;\nRestrict X-ray r...
# 184   \nZoom in on displayed image;\nView the regio...
# 185  \nSelect if the processing applies to the imag...
#
#                                    SRS Tags (Combined)  \
# 0    SRS.Allura.Manf.VerifySystem | SRS.Allura.Phys...
# 1    SRS.Allura.Func.VesselAnalysis.Accuracy | SRS....
# 2    SRS.Allura.Func.VesselAnalysis | SRS.Allura.Fu...
# 3                        SRS.Allura.Func.QACalibration
# 4    SRS.Allura.Func.VesselAnalysis | SRS.Allura.Fu...
# ..                                                 ...
# 181  SRS.Allura.Func.AngulateBeam | SRS.Allura.Func...
# 182  SRS.Allura.Intgr.Interfaces.RealTimeImageLink ...
# 183  SRS.Allura.Func.Move/ResetWedges | SRS.Allura....
# 184  SRS.Allura.Conf.SupportedConfigurations | SRS....
# 185              SRS.Allura.Func.SelectProcessingFocus
#
#                                                Content
# 0    The Manufacturer Engineer shall be able to ver...
# 1    Table:\nType of measurement\tAccuracy (systema...
# 2    The system shall provide vessel analysis for c...
# 3    All 2DQA applications and basic measurements (...
# 4    The system shall provide vessel analysis for c...
# ..                                                 ...
# 181  Changes the angle between beam and longitudina...
# 182  The system shall provide communication interfa...
# 183  Enables wedges to move in/out, or rotate. Rese...
# 184  The following FD configurations shall be suppo...
# 185  This function allows the user to select whethe...
#
# [186 rows x 4 columns]
# Data has been successfully written to C:\Users\320271965\Desktop\project 1 Traceability\BI\IGT_BI\1911traceability with uns srs content.xlsx

# %%
AZURE_OPENAI_API_KEY_3: 'f012e5450dfe45cb973d1b6341584c06'
AZURE_OPENAI_ENDPOINT_3: 'https://aicoe-open-ai-np-002.openai.azure.com/'
OPENAI_API_VERSION_3: '2023-07-01-preview'

CHAT_MODEL_3: 'gpt_35_turbo'
CHAT_DEPLOYMENT_3: 'aicoe-np-gpt35-turbo'

# %%
os.environ["AZURE_OPENAI_API_KEY_3"] = 'f012e5450dfe45cb973d1b6341584c06'
os.environ["AZURE_OPENAI_ENDPOINT_3"] = 'https://aicoe-open-ai-np-002.openai.azure.com/'
os.environ["OPENAI_API_VERSION_3"] = '2023-07-01-preview'

# %%
def initialize_chat_model(endpoint, api_key, deployment_name, version_num, model_name):
    return AzureChatOpenAI(azure_endpoint=endpoint, openai_api_key=api_key, 
                           deployment_name=deployment_name, openai_api_version=version_num,
                           model_name=model_name, temperature=0.0, max_tokens=2048)

# %%
model3 = initialize_chat_model('https://aicoe-open-ai-np-002.openai.azure.com/',
                              'f012e5450dfe45cb973d1b6341584c06',
                              'aicoe-np-gpt35-turbo', 
                              '2023-07-01-preview', 
                              'gpt_35_turbo')

# %%
def get_completion(prompt, model=model3,max_tokens=500): 
    message = HumanMessage(content=prompt)
    response = model.invoke([message])
    # response = model([message])
    return response.content



#def get_completion(prompt, model):
    message = HumanMessage(content=prompt)
    response = model.invoke([message])
    return response.content

# %%
def extract_values(response):
    is_same_match = re.search(r"is_same: (YES|NO)", response)
    is_same = is_same_match.group(1) if is_same_match else "ERROR: is_same not found"

    deviation_match = re.search(r"deviation: (\d+)%", response)  # Adjusted regex for deviation
    deviation = deviation_match.group(1) if deviation_match else "ERROR: deviation not found"

    missing_content_matches = re.findall(r"- (.*)", response)  # Adjusted regex for missing content
    missing_content = missing_content_matches if missing_content_matches else "ERROR: missing_content not found"

    return is_same, deviation, missing_content

# %%
# Assuming df_combined is the DataFrame and row 2 corresponds to index 1 (since indexing starts from 0)
row_index=9
uns_content = df_combined.iloc[row_index, 1]  # Second column (index 1) of row 2 (index 1)
srs_content = df_combined.iloc[row_index, 3]  # Fourth column (index 3) of row 2 (index 1)

# Format the prompt by inserting the extracted values
prompt = f"""
Your task is to compare {uns_content} and {srs_content}, enclosed in triple backticks.
uns_content is requirement given by user and srs_content is system requirements converted by test engineers.

input: ```{uns_content}, {srs_content}```
output:
Please answer below questions after comparing input, in same order.
1.) Whatever is in uns_content is being covered fully in srs_content or not? 
    is_same: YES/NO
2.) By how much percentage srs_content is deviated from uns_content?
    deviation: percentage
3.) If anything is missing from srs_content which is there in uns_content, state that clearly in pointers.
    missing_content: pointers
4.) Describe the deviation in this ?     
"""
response = get_completion(prompt, model3)


print(f"UNS content: {uns_content} \n\n\n SRS content: {srs_content}")
print(response)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[25], line 22
#       6 # Format the prompt by inserting the extracted values
#       7 prompt = f"""
#       8 Your task is to compare {uns_content} and {srs_content}, enclosed in triple backticks.
#       9 uns_content is requirement given by user and srs_content is system requirements converted by test engineers.
#    (...)
#      20 4.) Describe the deviation in this ?
#      21 """
# ---> 22 response = get_completion(prompt, model3)
#      25 print(f"UNS content: {uns_content} \n\n\n SRS content: {srs_content}")
#      26 print(response)
#
# Cell In[24], line 3, in get_completion(prompt, model, max_tokens)
#       1 def get_completion(prompt, model=model3,max_tokens=500):
#       2     message = HumanMessage(content=prompt)
# ----> 3     response = model.invoke([message])
#       4     # response = model([message])
#       5     return response.content
#
# File c:\Tools\MiniForge3\lib\site-packages\langchain_core\language_models\chat_models.py:286, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     275 def invoke(
#     276     self,
#     277     input: LanguageModelInput,
#    (...)
#     281     **kwargs: Any,
#     282 ) -> BaseMessage:
#     283     config = ensure_config(config)
#     284     return cast(
#     285         ChatGeneration,
# --> 286         self.generate_prompt(
#     287             [self._convert_input(input)],
#     288             stop=stop,
#     289             callbacks=config.get("callbacks"),
#     290             tags=config.get("tags"),
#     291             metadata=config.get("metadata"),
#     292             run_name=config.get("run_name"),
#     293             run_id=config.pop("run_id", None),
#     294             **kwargs,
#     295         ).generations[0][0],
#     296     ).message
#
# File c:\Tools\MiniForge3\lib\site-packages\langchain_core\language_models\chat_models.py:786, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     778 def generate_prompt(
#     779     self,
#     780     prompts: list[PromptValue],
#    (...)
#     783     **kwargs: Any,
#     784 ) -> LLMResult:
#     785     prompt_messages = [p.to_messages() for p in prompts]
# --> 786     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Tools\MiniForge3\lib\site-packages\langchain_core\language_models\chat_models.py:643, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     641         if run_managers:
#     642             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 643         raise e
#     644 flattened_outputs = [
#     645     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     646     for res in results
#     647 ]
#     648 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File c:\Tools\MiniForge3\lib\site-packages\langchain_core\language_models\chat_models.py:633, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     630 for i, m in enumerate(messages):
#     631     try:
#     632         results.append(
# --> 633             self._generate_with_cache(
#     634                 m,
#     635                 stop=stop,
#     636                 run_manager=run_managers[i] if run_managers else None,
#     637                 **kwargs,
#     638             )
#     639         )
#     640     except BaseException as e:
#     641         if run_managers:
#
# File c:\Tools\MiniForge3\lib\site-packages\langchain_core\language_models\chat_models.py:851, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     849 else:
#     850     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 851         result = self._generate(
#     852             messages, stop=stop, run_manager=run_manager, **kwargs
#     853         )
#     854     else:
#     855         result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Tools\MiniForge3\lib\site-packages\langchain_openai\chat_models\base.py:683, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     681     generation_info = {"headers": dict(raw_response.headers)}
#     682 else:
# --> 683     response = self.client.create(**payload)
#     684 return self._create_chat_result(response, generation_info)
#
# File c:\Tools\MiniForge3\lib\site-packages\openai\_utils\_utils.py:274, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     272             msg = f"Missing required argument: {quote(missing[0])}"
#     273     raise TypeError(msg)
# --> 274 return func(*args, **kwargs)
#
# File c:\Tools\MiniForge3\lib\site-packages\openai\resources\chat\completions.py:742, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, n, parallel_tool_calls, presence_penalty, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     704 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     705 def create(
#     706     self,
#    (...)
#     739     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     740 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     741     validate_response_format(response_format)
# --> 742     return self._post(
#     743         "/chat/completions",
#     744         body=maybe_transform(
#     745             {
#     746                 "messages": messages,
#     747                 "model": model,
#     748                 "frequency_penalty": frequency_penalty,
#     749                 "function_call": function_call,
#     750                 "functions": functions,
#     751                 "logit_bias": logit_bias,
#     752                 "logprobs": logprobs,
#     753                 "max_completion_tokens": max_completion_tokens,
#     754                 "max_tokens": max_tokens,
#     755                 "metadata": metadata,
#     756                 "n": n,
#     757                 "parallel_tool_calls": parallel_tool_calls,
#     758                 "presence_penalty": presence_penalty,
#     759                 "response_format": response_format,
#     760                 "seed": seed,
#     761                 "service_tier": service_tier,
#     762                 "stop": stop,
#     763                 "store": store,
#     764                 "stream": stream,
#     765                 "stream_options": stream_options,
#     766                 "temperature": temperature,
#     767                 "tool_choice": tool_choice,
#     768                 "tools": tools,
#     769                 "top_logprobs": top_logprobs,
#     770                 "top_p": top_p,
#     771                 "user": user,
#     772             },
#     773             completion_create_params.CompletionCreateParams,
#     774         ),
#     775         options=make_request_options(
#     776             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     777         ),
#     778         cast_to=ChatCompletion,
#     779         stream=stream or False,
#     780         stream_cls=Stream[ChatCompletionChunk],
#     781     )
#
# File c:\Tools\MiniForge3\lib\site-packages\openai\_base_client.py:1277, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1263 def post(
#    1264     self,
#    1265     path: str,
#    (...)
#    1272     stream_cls: type[_StreamT] | None = None,
#    1273 ) -> ResponseT | _StreamT:
#    1274     opts = FinalRequestOptions.construct(
#    1275         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1276     )
# -> 1277     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Tools\MiniForge3\lib\site-packages\openai\_base_client.py:954, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     951 else:
#     952     retries_taken = 0
# --> 954 return self._request(
#     955     cast_to=cast_to,
#     956     options=options,
#     957     stream=stream,
#     958     stream_cls=stream_cls,
#     959     retries_taken=retries_taken,
#     960 )
#
# File c:\Tools\MiniForge3\lib\site-packages\openai\_base_client.py:1058, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1055         err.response.read()
#    1057     log.debug("Re-raising status error")
# -> 1058     raise self._make_status_error_from_response(err.response) from None
#    1060 return self._process_response(
#    1061     cast_to=cast_to,
#    1062     options=options,
#    (...)
#    1066     retries_taken=retries_taken,
#    1067 )
#
# BadRequestError: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 4576 tokens (2528 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}

# %%
import pandas as pd

# List to hold the responses for each row
responses = []

# Iterate over the rows in df_combined
for index, row in df_combined.iterrows():
    try:
        uns_content = row.iloc[1]  # Second column
        srs_content = row.iloc[3]  # Fourth column
        
        
        prompt = f"""
        Your task is to compare {uns_content} and {srs_content}, enclosed in triple backticks.
        uns_content is requirement given by user and srs_content is system requirements converted by test engineers.
        
        input: ```{uns_content}, {srs_content}```
        output:
        Please answer below questions after comparing input, in same order.
        1.) Whatever is in uns_content is being covered fully in srs_content or not? 
            is_same: YES/NO
        2.) By how much percentage srs_content is deviated from uns_content?
            deviation: percentage
        3.) If anything is missing from srs_content which is there in uns_content, state that clearly in pointers.
            missing_content: pointers
        4.) Describe the deviation in this 
        """
        
       
        response = get_completion(prompt, model3)  
        
        # Add the response to the list
        responses.append({
            'Row': index + 1,
            'uns_content': uns_content,
            'srs_content': srs_content,
            'Response': response
        })

    except Exception as e:
        # If there is an error, print a message and skip to the next row
        print(f"Error processing row {index + 1}: {e}")
        continue  # Skip to the next iteration


response_df = pd.DataFrame(responses)


output_file_path = r'C:\Users\320271965\Desktop\project 1 Traceability\BI\Output\LLM4response.xlsx'
response_df.to_excel(output_file_path, index=False)

print(f"All responses saved to {output_file_path}")
# Out:
# Error processing row 1: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, your messages resulted in 9268 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 8: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, your messages resulted in 9830 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 9: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 5774 tokens (3726 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 10: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 4590 tokens (2542 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 16: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 4781 tokens (2733 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 17: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, your messages resulted in 14288 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 21: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 5281 tokens (3233 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 27: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 5554 tokens (3506 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 33: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 5033 tokens (2985 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 40: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 4581 tokens (2533 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 41: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 5310 tokens (3262 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 42: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, your messages resulted in 7179 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 44: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, your messages resulted in 4839 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 60: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, your messages resulted in 4334 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 61: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 6086 tokens (4038 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 62: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 6018 tokens (3970 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 67: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 5312 tokens (3264 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 70: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 4957 tokens (2909 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 71: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 5172 tokens (3124 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 85: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 4865 tokens (2817 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 88: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, your messages resulted in 7717 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 103: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 4511 tokens (2463 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 114: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, your messages resulted in 4289 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 118: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 4425 tokens (2377 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 120: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 4598 tokens (2550 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 124: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 4179 tokens (2131 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 127: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 4803 tokens (2755 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 130: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 5283 tokens (3235 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 134: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 4138 tokens (2090 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 141: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 5365 tokens (3317 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 142: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 4731 tokens (2683 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 144: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 4653 tokens (2605 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 146: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 5905 tokens (3857 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 148: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, your messages resulted in 4468 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 163: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 4572 tokens (2524 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 168: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 5513 tokens (3465 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 169: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, your messages resulted in 7218 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 174: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 5595 tokens (3547 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 185: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, your messages resulted in 4337 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# All responses saved to C:\Users\320271965\Desktop\project 1 Traceability\BI\Output\LLM4response.xlsx

# %%
import pandas as pd
import re  # For extracting the parts of the response

# List to hold the responses for each row
responses = []

# Iterate over the rows in df_combined
for index, row in df_combined.iterrows():
    try:
        uns_content = row.iloc[1]  # Second column
        srs_content = row.iloc[3]  # Fourth column
        
        # Format the prompt with the values from the current row
        prompt = f"""
        Your task is to compare {uns_content} and {srs_content}, enclosed in triple backticks.
        uns_content is requirement given by user and srs_content is system requirements converted by test engineers.
        
        input: ```{uns_content}, {srs_content}```
        output:
        Please answer below questions after comparing input, in the same order.
        1.) Whatever is in uns_content is being covered fully in srs_content or not? 
            is_same: YES/NO
        2.) By how much percentage srs_content is deviated from uns_content?
            deviation: percentage
        3.) If anything is missing from srs_content which is there in uns_content, state that clearly in pointers.
            missing_content: pointers
        4.) Describe the deviation in this
        """
        
        # Mocked LLM response (Replace with actual response)
        response = get_completion(prompt, model3)  # Replace with actual response from LLM
        
        # Example response:
        # response = """
        # 1.) is_same: NO
        # 2.) deviation: 60%
        # 3.) missing_content: Viewer for logging and tracing, Capabilities for content scaling...
        # 4.) The srs_content is missing several requirements...
        # """
        
        # Extracting the is_same, deviation, missing_content, and deviation_description using regular expressions
        is_same = re.search(r'is_same:\s*(YES|NO)', response)
        deviation = re.search(r'deviation:\s*([\d%]+)', response)
        missing_content = re.search(r'missing_content:\s*(.*?)(?:\n|$)', response, re.DOTALL)
        deviation_description = re.search(r'4\.\)\s*(.*)', response, re.DOTALL)
        
        # Safely get the matched values, or default to 'N/A' if not found
        is_same_value = is_same.group(1) if is_same else 'N/A'
        deviation_value = deviation.group(1) if deviation else 'N/A'
        missing_content_value = missing_content.group(1).strip() if missing_content else 'N/A'
        deviation_description_value = deviation_description.group(1).strip() if deviation_description else 'N/A'
        
        # Add the response to the list with separate columns
        responses.append({
            'Row': index + 1,
            'uns_content': uns_content,
            'srs_content': srs_content,
            'is_same': is_same_value,
            'deviation': deviation_value,
            'missing_content': missing_content_value,
            'deviation_description': deviation_description_value
        })

    except Exception as e:
        # If there is an error, print a message and skip to the next row
        print(f"Error processing row {index + 1}: {e}")
        continue  # Skip to the next iteration

# Convert the responses list to a DataFrame
response_df = pd.DataFrame(responses)

# Save the DataFrame to an Excel file
output_file_path = r'C:\Users\320271965\Desktop\project 1 Traceability\BI\Output\LLM4___response.xlsx'
response_df.to_excel(output_file_path, index=False)

print(f"All responses saved to {output_file_path}")
# Out:
# Error processing row 1: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, your messages resulted in 9269 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 8: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, your messages resulted in 9831 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 9: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 5775 tokens (3727 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 10: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 4591 tokens (2543 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 16: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 4782 tokens (2734 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 17: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, your messages resulted in 14289 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 21: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 5282 tokens (3234 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 27: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 5555 tokens (3507 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 33: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 5034 tokens (2986 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 40: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 4582 tokens (2534 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 41: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 5311 tokens (3263 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 42: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, your messages resulted in 7180 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 44: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, your messages resulted in 4840 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 60: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, your messages resulted in 4335 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 61: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 6087 tokens (4039 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 62: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 6019 tokens (3971 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 67: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 5313 tokens (3265 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 70: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 4958 tokens (2910 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 71: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 5173 tokens (3125 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 85: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 4866 tokens (2818 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 88: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, your messages resulted in 7718 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 103: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 4512 tokens (2464 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 114: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, your messages resulted in 4290 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 118: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 4426 tokens (2378 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 120: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 4599 tokens (2551 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 124: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 4180 tokens (2132 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 127: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 4804 tokens (2756 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 130: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 5284 tokens (3236 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 134: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 4139 tokens (2091 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 141: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 5366 tokens (3318 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 142: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 4732 tokens (2684 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 144: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 4654 tokens (2606 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 146: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 5906 tokens (3858 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 148: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, your messages resulted in 4469 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 163: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 4573 tokens (2525 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 168: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 5514 tokens (3466 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 169: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, your messages resulted in 7219 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 174: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 5596 tokens (3548 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 185: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, your messages resulted in 4338 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# All responses saved to C:\Users\320271965\Desktop\project 1 Traceability\BI\Output\LLM4___response.xlsx

# %%
print(df_combined)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(df_combined)
#
# NameError: name 'df_combined' is not defined

# %%
import pandas as pd
import re  # For extracting the parts of the response

dff_combined=read_excel(r'C:\Users\320271965\Desktop\project 1 Traceability\BI\IGT_BI\traceability with content.xlsx')

# List to hold the responses for each row
responses = []

# Iterate over the rows in df_combined
for index, row in dff_combined.iterrows():
    try:
        uns_content = row.iloc[1]  # Second column
        srs_content = row.iloc[3]  # Fourth column
        
        # Format the prompt with the values from the current row
        prompt = f"""
        Your task is to compare {uns_content} and {srs_content}, enclosed in triple backticks.
        uns_content is requirement given by user and srs_content is system requirements converted by test engineers.
        
        input: ```{uns_content}, {srs_content}```
        output:
        Please answer below questions after comparing input, in the same order.
        1.) Whatever is in uns_content is being covered fully in srs_content or not? 
            is_same: YES/NO
        2.) If anything is missing in the srs_contentwhich is there in uns_content, state that clearly in pointers.
            missing_content: pointers
        """
        
        # Mocked LLM response (Replace with actual response)
        response = get_completion(prompt, model3,max_tokens=1000)  # Replace with actual response from LLM
        
        # Example response:
        # response = """
        # 1.) is_same: NO
        # 2.) deviation: 60%
        # 3.) missing_content: Viewer for logging and tracing, Capabilities for content scaling...
        # 4.) The srs_content is missing several requirements...
        # """
        
        # Extracting the is_same, deviation, missing_content, and deviation_description using regular expressions
        is_same = re.search(r'is_same:\s*(YES|NO)', response)
        missing_content = re.search(r'missing_content:\s*(.*?)(?:\n|$)', response, re.DOTALL)
        
        # Safely get the matched values, or default to 'N/A' if not found
        is_same_value = is_same.group(1) if is_same else 'N/A'
        missing_content_value = missing_content.group(1).strip() if missing_content else 'N/A'
        
        # Add the response to the list with separate columns
        responses.append({
            'Row': index + 1,
            'uns_content': uns_content,
            'srs_content': srs_content,
            'is_same': is_same_value,
            'missing_content': missing_content_value,
        })

    except Exception as e:
        # If there is an error, print a message and skip to the next row
        print(f"Error processing row {index + 1}: {e}")
        continue  # Skip to the next iteration

# Convert the responses list to a DataFrame
response_df = pd.DataFrame(responses)

# Save the DataFrame to an Excel file
output_file_path = r'C:\Users\320271965\Desktop\project 1 Traceability\BI\Output\ver2LLM___response.xlsx'
response_df.to_excel(output_file_path, index=False)

print(f"All responses saved to {output_file_path}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 4
#       1 import pandas as pd
#       2 import re  # For extracting the parts of the response
# ----> 4 dff_combined=read_excel(r'C:\Users\320271965\Desktop\project 1 Traceability\BI\IGT_BI\traceability with content.xlsx')
#       6 # List to hold the responses for each row
#       7 responses = []
#
# NameError: name 'read_excel' is not defined

# %%
import pandas as pd
import re  # For extracting the parts of the response

# Load your Excel file
dff_combined = pd.read_excel(r'C:\Users\320271965\Desktop\project 1 Traceability\BI\IGT_BI\traceability with content.xlsx')

# Function to get the LLM response
def get_completion(prompt, model, max_tokens=800):
    message = HumanMessage(content=prompt)
    response = model.invoke([message])
    return response.content

# List to hold the responses for each row
responses = []

# Iterate over the rows in df_combined
for index, row in dff_combined.iterrows():
    try:
        uns_content = row.iloc[1]  # Assuming the second column is the UNS content
        srs_content = row.iloc[3]  # Assuming the fourth column is the SRS content
        
        # Format the prompt with the values from the current row
        prompt = f"""
        Your task is to compare the content provided below, enclosed in triple backticks.
        'uns_content' is the user requirement, while 'srs_content' is the system requirement by test engineers.
        
        Input:
        ```{uns_content}```
        ```{srs_content}```
        
        Output:
        Please answer the following questions in the same order:
        1. Does 'uns_content' fully align with 'srs_content'?
           Answer with: **is_same: YES/NO**
        2. If any content is missing in 'srs_content' that is present in 'uns_content', clearly list it as pointers.
            Answer with: **missing_content:
        """
        
        # Get response from the LLM (make sure `model3` is defined)
        response = get_completion(prompt, model3, max_tokens=1000) 
        
        # Use regular expressions to extract the is_same and missing_content
        is_same = re.search(r'is_same:\s*(YES|NO)', response)
        missing_content = re.search(r'missing_content:\s*(.*?)(?:\n|$)', response, re.DOTALL)
        
        # Safely get the matched values, or default to 'N/A' if not found
        is_same_value = is_same.group(1) if is_same else 'N/A'
        missing_content_value = missing_content.group(1).strip() if missing_content else 'N/A'
        
        # Add the response to the list with separate columns
        responses.append({
            'uns_content': uns_content,
            'srs_content': srs_content,
            'uns aligns with srs': is_same_value,
            'missing_content': missing_content_value,
        })

    except Exception as e:
        # If there is an error, print a message and skip to the next row
        print(f"Error processing row {index + 1}: {e}")
        continue  # Skip to the next iteration

# Convert the responses list to a DataFrame
response_df = pd.DataFrame(responses)

# Save the DataFrame to an Excel file (append to existing file)
output_file_path = r'C:\Users\320271965\Desktop\project 1 Traceability\BI\Output\ver2LLM___response.xlsx'

response_df.to_excel(output_file_path, index=False)

print(f"All responses have been saved to {output_file_path}.")
# Out:
# Error processing row 8: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 4576 tokens (2528 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 17: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 5461 tokens (3413 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 42: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 4524 tokens (2476 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 88: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 4762 tokens (2714 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# Error processing row 169: Error code: 400 - {'error': {'message': "This model's maximum context length is 4096 tokens. However, you requested 4684 tokens (2636 in the messages, 2048 in the completion). Please reduce the length of the messages or completion.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# All responses have been saved to C:\Users\320271965\Desktop\project 1 Traceability\BI\Output\ver2LLM___response.xlsx.

# %%
# Assuming df_combined is the DataFrame and row 2 corresponds to index 1 (since indexing starts from 0)
def get_completion(prompt, model, max_tokens=800):
    message = HumanMessage(content=prompt)
    response = model.invoke([message])
    return response.content

row_index=4
uns_content = dff_combined.iloc[row_index, 1]  # Second column (index 1) of row 2 (index 1)
srs_content = dff_combined.iloc[row_index, 3]  # Fourth column (index 3) of row 2 (index 1)

# Format the prompt by inserting the extracted values
prompt = f"""
Your task is to compare {uns_content} and {srs_content}, enclosed in triple backticks.
uns_content is requirement given by user and srs_content is system requirements converted by test engineers.

input: ```{uns_content}, {srs_content}```
output:
Please answer below questions after comparing input, in same order.
1.) Whatever is in uns_content is its core meaning being covered fully in srs_content or not? 
    is_same: YES/NO
2.) If anything is missing in srs_content which is there in uns_content, state that.
"""
response = get_completion(prompt, model3)


print(f"UNS content: {uns_content} \n\n\n SRS content: {srs_content}")
print(response)
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File c:\Tools\MiniForge3\lib\site-packages\httpx\_transports\default.py:72, in map_httpcore_exceptions()
#      71 try:
# ---> 72     yield
#      73 except Exception as exc:
#
# File c:\Tools\MiniForge3\lib\site-packages\httpx\_transports\default.py:236, in HTTPTransport.handle_request(self, request)
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Tools\MiniForge3\lib\site-packages\httpcore\_sync\connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#
# File c:\Tools\MiniForge3\lib\site-packages\httpcore\_sync\connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#
# File c:\Tools\MiniForge3\lib\site-packages\httpcore\_sync\connection.py:99, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
# ---> 99     raise exc
#     101 return self._connection.handle_request(request)
#
# File c:\Tools\MiniForge3\lib\site-packages\httpcore\_sync\connection.py:76, in HTTPConnection.handle_request(self, request)
#      75 if self._connection is None:
# ---> 76     stream = self._connect(request)
#      78     ssl_object = stream.get_extra_info("ssl_object")
#
# File c:\Tools\MiniForge3\lib\site-packages\httpcore\_sync\connection.py:122, in HTTPConnection._connect(self, request)
#     121 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 122     stream = self._network_backend.connect_tcp(**kwargs)
#     123     trace.return_value = stream
#
# File c:\Tools\MiniForge3\lib\site-packages\httpcore\_backends\sync.py:205, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     200 exc_map: ExceptionMapping = {
#     201     socket.timeout: ConnectTimeout,
#     202     OSError: ConnectError,
#     203 }
# --> 205 with map_exceptions(exc_map):
#     206     sock = socket.create_connection(
#     207         address,
#     208         timeout,
#     209         source_address=source_address,
#     210     )
#
# File c:\Tools\MiniForge3\lib\contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File c:\Tools\MiniForge3\lib\site-packages\httpcore\_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [Errno 11001] getaddrinfo failed
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File c:\Tools\MiniForge3\lib\site-packages\openai\_base_client.py:990, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     989 try:
# --> 990     response = self._client.send(
#     991         request,
#     992         stream=stream or self._should_stream_response_body(request=request),
#     993         **kwargs,
#     994     )
#     995 except httpx.TimeoutException as err:
#
# File c:\Tools\MiniForge3\lib\site-packages\httpx\_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#
# File c:\Tools\MiniForge3\lib\site-packages\httpx\_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#
# File c:\Tools\MiniForge3\lib\site-packages\httpx\_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#
# File c:\Tools\MiniForge3\lib\site-packages\httpx\_client.py:1027, in Client._send_single_request(self, request)
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#
# File c:\Tools\MiniForge3\lib\site-packages\httpx\_transports\default.py:235, in HTTPTransport.handle_request(self, request)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)
#     233     extensions=request.extensions,
#     234 )
# --> 235 with map_httpcore_exceptions():
#     236     resp = self._pool.handle_request(req)
#
# File c:\Tools\MiniForge3\lib\contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File c:\Tools\MiniForge3\lib\site-packages\httpx\_transports\default.py:89, in map_httpcore_exceptions()
#      88 message = str(exc)
# ---> 89 raise mapped_exc(message) from exc
#
# ConnectError: [Errno 11001] getaddrinfo failed
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[35], line 23
#      11 # Format the prompt by inserting the extracted values
#      12 prompt = f"""
#      13 Your task is to compare {uns_content} and {srs_content}, enclosed in triple backticks.
#      14 uns_content is requirement given by user and srs_content is system requirements converted by test engineers.
#    (...)
#      21 2.) If anything is missing in srs_content which is there in uns_content, state that.
#      22 """
# ---> 23 response = get_completion(prompt, model3)
#      26 print(f"UNS content: {uns_content} \n\n\n SRS content: {srs_content}")
#      27 print(response)
#
# Cell In[35], line 4, in get_completion(prompt, model, max_tokens)
#       2 def get_completion(prompt, model, max_tokens=800):
#       3     message = HumanMessage(content=prompt)
# ----> 4     response = model.invoke([message])
#       5     return response.content
#
# File c:\Tools\MiniForge3\lib\site-packages\langchain_core\language_models\chat_models.py:286, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     275 def invoke(
#     276     self,
#     277     input: LanguageModelInput,
#    (...)
#     281     **kwargs: Any,
#     282 ) -> BaseMessage:
#     283     config = ensure_config(config)
#     284     return cast(
#     285         ChatGeneration,
# --> 286         self.generate_prompt(
#     287             [self._convert_input(input)],
#     288             stop=stop,
#     289             callbacks=config.get("callbacks"),
#     290             tags=config.get("tags"),
#     291             metadata=config.get("metadata"),
#     292             run_name=config.get("run_name"),
#     293             run_id=config.pop("run_id", None),
#     294             **kwargs,
#     295         ).generations[0][0],
#     296     ).message
#
# File c:\Tools\MiniForge3\lib\site-packages\langchain_core\language_models\chat_models.py:786, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     778 def generate_prompt(
#     779     self,
#     780     prompts: list[PromptValue],
#    (...)
#     783     **kwargs: Any,
#     784 ) -> LLMResult:
#     785     prompt_messages = [p.to_messages() for p in prompts]
# --> 786     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Tools\MiniForge3\lib\site-packages\langchain_core\language_models\chat_models.py:643, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     641         if run_managers:
#     642             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 643         raise e
#     644 flattened_outputs = [
#     645     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     646     for res in results
#     647 ]
#     648 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File c:\Tools\MiniForge3\lib\site-packages\langchain_core\language_models\chat_models.py:633, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     630 for i, m in enumerate(messages):
#     631     try:
#     632         results.append(
# --> 633             self._generate_with_cache(
#     634                 m,
#     635                 stop=stop,
#     636                 run_manager=run_managers[i] if run_managers else None,
#     637                 **kwargs,
#     638             )
#     639         )
#     640     except BaseException as e:
#     641         if run_managers:
#
# File c:\Tools\MiniForge3\lib\site-packages\langchain_core\language_models\chat_models.py:851, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     849 else:
#     850     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 851         result = self._generate(
#     852             messages, stop=stop, run_manager=run_manager, **kwargs
#     853         )
#     854     else:
#     855         result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Tools\MiniForge3\lib\site-packages\langchain_openai\chat_models\base.py:683, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     681     generation_info = {"headers": dict(raw_response.headers)}
#     682 else:
# --> 683     response = self.client.create(**payload)
#     684 return self._create_chat_result(response, generation_info)
#
# File c:\Tools\MiniForge3\lib\site-packages\openai\_utils\_utils.py:274, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     272             msg = f"Missing required argument: {quote(missing[0])}"
#     273     raise TypeError(msg)
# --> 274 return func(*args, **kwargs)
#
# File c:\Tools\MiniForge3\lib\site-packages\openai\resources\chat\completions.py:742, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, n, parallel_tool_calls, presence_penalty, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     704 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     705 def create(
#     706     self,
#    (...)
#     739     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     740 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     741     validate_response_format(response_format)
# --> 742     return self._post(
#     743         "/chat/completions",
#     744         body=maybe_transform(
#     745             {
#     746                 "messages": messages,
#     747                 "model": model,
#     748                 "frequency_penalty": frequency_penalty,
#     749                 "function_call": function_call,
#     750                 "functions": functions,
#     751                 "logit_bias": logit_bias,
#     752                 "logprobs": logprobs,
#     753                 "max_completion_tokens": max_completion_tokens,
#     754                 "max_tokens": max_tokens,
#     755                 "metadata": metadata,
#     756                 "n": n,
#     757                 "parallel_tool_calls": parallel_tool_calls,
#     758                 "presence_penalty": presence_penalty,
#     759                 "response_format": response_format,
#     760                 "seed": seed,
#     761                 "service_tier": service_tier,
#     762                 "stop": stop,
#     763                 "store": store,
#     764                 "stream": stream,
#     765                 "stream_options": stream_options,
#     766                 "temperature": temperature,
#     767                 "tool_choice": tool_choice,
#     768                 "tools": tools,
#     769                 "top_logprobs": top_logprobs,
#     770                 "top_p": top_p,
#     771                 "user": user,
#     772             },
#     773             completion_create_params.CompletionCreateParams,
#     774         ),
#     775         options=make_request_options(
#     776             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     777         ),
#     778         cast_to=ChatCompletion,
#     779         stream=stream or False,
#     780         stream_cls=Stream[ChatCompletionChunk],
#     781     )
#
# File c:\Tools\MiniForge3\lib\site-packages\openai\_base_client.py:1277, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1263 def post(
#    1264     self,
#    1265     path: str,
#    (...)
#    1272     stream_cls: type[_StreamT] | None = None,
#    1273 ) -> ResponseT | _StreamT:
#    1274     opts = FinalRequestOptions.construct(
#    1275         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1276     )
# -> 1277     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Tools\MiniForge3\lib\site-packages\openai\_base_client.py:954, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     951 else:
#     952     retries_taken = 0
# --> 954 return self._request(
#     955     cast_to=cast_to,
#     956     options=options,
#     957     stream=stream,
#     958     stream_cls=stream_cls,
#     959     retries_taken=retries_taken,
#     960 )
#
# File c:\Tools\MiniForge3\lib\site-packages\openai\_base_client.py:1014, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1011 log.debug("Encountered Exception", exc_info=True)
#    1013 if remaining_retries > 0:
# -> 1014     return self._retry_request(
#    1015         input_options,
#    1016         cast_to,
#    1017         retries_taken=retries_taken,
#    1018         stream=stream,
#    1019         stream_cls=stream_cls,
#    1020         response_headers=None,
#    1021     )
#    1023 log.debug("Raising connection error")
#    1024 raise APIConnectionError(request=request) from err
#
# File c:\Tools\MiniForge3\lib\site-packages\openai\_base_client.py:1092, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1088 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1089 # different thread if necessary.
#    1090 time.sleep(timeout)
# -> 1092 return self._request(
#    1093     options=options,
#    1094     cast_to=cast_to,
#    1095     retries_taken=retries_taken + 1,
#    1096     stream=stream,
#    1097     stream_cls=stream_cls,
#    1098 )
#
# File c:\Tools\MiniForge3\lib\site-packages\openai\_base_client.py:1014, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1011 log.debug("Encountered Exception", exc_info=True)
#    1013 if remaining_retries > 0:
# -> 1014     return self._retry_request(
#    1015         input_options,
#    1016         cast_to,
#    1017         retries_taken=retries_taken,
#    1018         stream=stream,
#    1019         stream_cls=stream_cls,
#    1020         response_headers=None,
#    1021     )
#    1023 log.debug("Raising connection error")
#    1024 raise APIConnectionError(request=request) from err
#
# File c:\Tools\MiniForge3\lib\site-packages\openai\_base_client.py:1092, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1088 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1089 # different thread if necessary.
#    1090 time.sleep(timeout)
# -> 1092 return self._request(
#    1093     options=options,
#    1094     cast_to=cast_to,
#    1095     retries_taken=retries_taken + 1,
#    1096     stream=stream,
#    1097     stream_cls=stream_cls,
#    1098 )
#
# File c:\Tools\MiniForge3\lib\site-packages\openai\_base_client.py:1024, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1014         return self._retry_request(
#    1015             input_options,
#    1016             cast_to,
#    (...)
#    1020             response_headers=None,
#    1021         )
#    1023     log.debug("Raising connection error")
# -> 1024     raise APIConnectionError(request=request) from err
#    1026 log.debug(
#    1027     'HTTP Response: %s %s "%i %s" %s',
#    1028     request.method,
#    (...)
#    1032     response.headers,
#    1033 )
#    1034 log.debug("request_id: %s", response.headers.get("x-request-id"))
#
# APIConnectionError: Connection error.

# %%
import pandas as pd
from openai import AzureOpenAI
from dotenv import load_dotenv

# Function to interact with the model
def get_completion(prompt, model=model3, max_tokens=500):
    message = HumanMessage(content=prompt)
    response = model.invoke([message])
    return response.content

# Load the DataFrame (make sure your file path and sheet name are correct)
input_file_path = r'C:\Users\320271965\Desktop\project 1 Traceability\BI\Data\UID\CombinedOutputflexibleviewing.xlsx'
combined_df1 = pd.read_excel(input_file_path)

# List to store results
results = []

# Iterate through each row in the DataFrame (Limited to 150 rows)


for index, row in combined_df1.iterrows(): 

    uid_tag = row['Uid tag']  # Assuming UID tag is in this column
    uid_content = row.iloc[1]  # Adjust column index as per your data
    srs_tag = row['Srs tag']  # Assuming SRS tag is in this column
    srs_content = row.iloc[3]  # Adjust column index as per your data

    # Generate prompt
    prompt = f"""
    I have two pieces of content that need to be compared:

    UID Content:
    ```{uid_content}```

    SRS Content:
    ```{srs_content}```

    Please answer the following questions:

    1. Is there similarity between the contents?

       - Answer with: **what is similar? and what is missing or not similar?**
   
    """

    # Get response from the model
    try:
        response = get_completion(prompt)
    except Exception as e:
        response = f"Error: {e}"

    # Store the results in a dictionary
    results.append({
        'UID Tag': uid_tag,
        'UID Content': uid_content,
        'SRS Tag': srs_tag,
        'SRS Content': srs_content,
        'Comparison Result': response
    })

# Convert results to a DataFrame
output_df = pd.DataFrame(results)

output_path = r'C:\Users\320271965\Desktop\project 1 Traceability\BI\Data\Comparison_Output_content150.xlsx'
output_df.to_excel(output_path, index=False)


print(f"Comparison results for 150 rows have been saved to {output_path}.")

# %%
import pandas as pd

# Load the original Excel file and specify the sheet
input_file_path = r'C:\Users\320271965\Desktop\project 1 Traceability\BI\Output\LLM___response.xlsx'

# Read the sheet into a DataFrame
df = pd.read_excel(input_file_path)

# Drop the 'deviation' column
df_modified = df.drop(columns=['deviation'])

# Save the modified DataFrame to a new Excel file
output_file_path = r'C:\Users\320271965\Desktop\project 1 Traceability\BI\Output\LLM_responses_no_deviation.xlsx'
df_modified.to_excel(output_file_path, index=False)

print(f"Column 'deviation' has been dropped and saved to a new file: {output_file_path}")
# Out:
# Column 'deviation' has been dropped and saved to a new file: C:\Users\320271965\Desktop\project 1 Traceability\BI\Output\LLM_responses_no_deviation.xlsx
